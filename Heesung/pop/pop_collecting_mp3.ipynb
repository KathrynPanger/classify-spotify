# %%
from spotipy.oauth2 import SpotifyClientCredentials
import matplotlib.pyplot as plt
import pandas as pd
import requests
import spotipy 
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import requests
import json
import re
import requests
import urllib.request
import re
from bs4 import BeautifulSoup
import os

# %%
from config import cid
from config import secret
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
dataframe_1=pd.read_csv("pop_track_dataframe_1.csv")
dataframe_1.head()
# Out:
#    Unnamed: 0 Genre   Track Name                Track ID  \
# 0           0   pop  False Alarm  23xqdYb5ViDUx0BOL2mGq6
# 1           1   pop    New Light  40FLJc17FMZaPmCQEEZgB0
# 2           2   pop     The Mack  2fUZ3aMp8amSaV0mp8s6rQ
# 3           3   pop   Slow Hands  2cOUlop2ZakjOKe4WinesN
# 4           4   pop    THat Part  2yJ9GVCLMmzBBfQAnfzlwr
#
#                                         Preview_link
# 0  https://p.scdn.co/mp3-preview/c1ab5515139265ea...
# 1  https://p.scdn.co/mp3-preview/213ffa7ca413185c...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
dataframe_2=pd.read_csv("pop_track_dataframe_2.csv")
dataframe_2.head()
# Out:
#    Unnamed: 0 Genre                            Track Name  \
# 0           0   pop                            Youngblood
# 1           1   pop                   Young And Beautiful
# 2           2   pop                              Starving
# 3           3   pop                       This Is America
# 4           4   pop  Still Got Time (feat. PARTYNEXTDOOR)
#
#                  Track ID                                       Preview_link
# 0  2iUXsYOEPhVqEBwsqP70rE                                                NaN
# 1  2nMeu6UenVvwUktBCpLMK9                                                NaN
# 2  6875MeXyCW0wLyT72Eetmo                                                NaN
# 3  0b9oOr2ZgvyQu88wzixux9  https://p.scdn.co/mp3-preview/01afc9c7c44d7b4b...
# 4  000xQL6tZNLJzIrtIgxqSl  https://p.scdn.co/mp3-preview/cc28d32b3c106428...

# %%
dataframe_3 = pd.read_csv("pop_track_dataframe_3.csv")
dataframe_3.head()
# Out:
#    Unnamed: 0 Genre                                         Track Name  \
# 0           0   pop                                    Maybe It's Time
# 1           1   pop                                          New Rules
# 2           2   pop  All My Friends (feat. Tinashe & Chance the Rap...
# 3           3   pop                                         I'm a Mess
# 4           4   pop                                  Love On The Brain
#
#                  Track ID                                       Preview_link
# 0  6jMbPsH6lTOLs5n8Af26AG                                                NaN
# 1  2xJCMIJfcNYDc5iR0sAm2O  https://p.scdn.co/mp3-preview/75a1b521de23958a...
# 2  6TaqooOXAEcijL6G1AWS2K  https://p.scdn.co/mp3-preview/65df530e5059704e...
# 3  3KiktyOxQd2Z0bmnabgRq2  https://p.scdn.co/mp3-preview/32028b3d85964481...
# 4  2aksifNn5ph8igDOkPBA02                                                NaN

# %%
final_df = pd.concat([dataframe_1, dataframe_2, dataframe_3], ignore_index=True)
final_df
# Out:
#      Unnamed: 0 Genre                                         Track Name  \
# 0             0   pop                                        False Alarm
# 1             1   pop                                          New Light
# 2             2   pop                                           The Mack
# 3             3   pop                                         Slow Hands
# 4             4   pop                                          THat Part
# 5             5   pop                                        Say My Name
# 6             6   pop                                        Wild Things
# 7             7   pop                                          Hot N*gga
# 8             8   pop                                        Fight Night
# 9             9   pop                        Always Remember Us This Way
# 10           10   pop                                              Girls
# 11           11   pop                                      We Don't Care
# ...

# %%
final_pop_merge_df = final_df.dropna(how = 'any')
final_pop_merge_df = final_pop_merge_df.drop_duplicates(subset=['Track ID'],keep='last')
final_pop_merge_df.reset_index()
final_pop_merge_df.drop(['Unnamed: 0'], axis=1)
final_pop_merge_df.to_csv("pop.csv")

# %%
pop = pd.read_csv("pop.csv")
pop
# Out:
#      Unnamed: 0  Unnamed: 0.1 Genre  \
# 0             0             0   pop
# 1             1             1   pop
# 2             5             5   pop
# 3            11            11   pop
# 4            14            14   pop
# 5            15            15   pop
# 6            17            17   pop
# 7            27            27   pop
# 8            30            30   pop
# 9            33            33   pop
# 10           34            34   pop
# 11           37            37   pop
# 12           39            39   pop
# 13           43            43   pop
# 14           44            44   pop
# 15           62            62   pop
# 16           63            63   pop
# 17           64            64   pop
# 18           69            69   pop
# 19           73            73   pop
# 20           74            74   pop
# 21           75            75   pop
# 22           82            82   pop
# 23           85            85   pop
# 24           87            87   pop
# ...

# %%
preview_list = pop['Preview_link'].tolist()
print(preview_list)
genre_list = pop['Genre'].tolist()
print(genre_list)
track_name_list = pop['Track Name'].tolist()
print(track_name_list)
# Out:
# ['https://p.scdn.co/mp3-preview/c1ab5515139265ead72f7a234137790ab22270a4?cid=577c3414ccf54576a289735f10e3ee13', 'https://p.scdn.co/mp3-preview/213ffa7ca413185c59a8811102048c07cd74494d?cid=577c3414ccf54576a289735f10e3ee13', 'https://p.scdn.co/mp3-preview/89e0ed2f21273e777832d67de4851c8137ee5c8d?cid=577c3414ccf54576a289735f10e3ee13', 'https://p.scdn.co/mp3-preview/893bca5eb7f90017390e26a88c584edd79492539?cid=577c3414ccf54576a289735f10e3ee13', 'https://p.scdn.co/mp3-preview/d50dfb78af7cb29f6363ba1a0d2cbdd707ee137c?cid=577c3414ccf54576a289735f10e3ee13', 'https://p.scdn.co/mp3-preview/900dc33cad986d311dfbe7e87d7da0efdb921f98?cid=577c3414ccf54576a289735f10e3ee13', 'https://p.scdn.co/mp3-preview/3e1d6ac23099c42068fff3f52c3fa8ddad86d36f?cid=577c3414ccf54576a289735f10e3ee13', 'https://p.scdn.co/mp3-preview/96969a8f4009660f5bf7eed23c70d1a16e8ab504?cid=577c3414ccf54576a289735f10e3ee13', 'https://p.scdn.co/mp3-preview/26fc2318d6ebad09ae7aed7adfce2b28413cea7e?cid=577c3414ccf54576a289735f10e3ee13'
# ...

# %%
os.chdir('/Users/heesungshim/Desktop/2_Homework_BTC/final_group_project/pop/pop_mp3')
for n, a_link in enumerate(preview_list):
    track_name = track_name_list[n].replace(' ', '_')
    track_name = track_name.replace('""', "''")
    track_name = track_name.replace("'", '_')
    track_name = track_name.replace('(', '_')
    track_name = track_name.replace(')', '_')
    track_name = track_name.replace('&', '_')
    a_output = genre_list[n]+'_'+str(n)+'_'+ track_name +'.mp3'
    cmd = "wget -O %s %s" % (a_output, a_link)
    print(cmd)
    os.system(cmd)
# Out:
# wget -O pop_0_False_Alarm.mp3 https://p.scdn.co/mp3-preview/c1ab5515139265ead72f7a234137790ab22270a4?cid=577c3414ccf54576a289735f10e3ee13
# wget -O pop_1_New_Light.mp3 https://p.scdn.co/mp3-preview/213ffa7ca413185c59a8811102048c07cd74494d?cid=577c3414ccf54576a289735f10e3ee13
# wget -O pop_2_Say_My_Name.mp3 https://p.scdn.co/mp3-preview/89e0ed2f21273e777832d67de4851c8137ee5c8d?cid=577c3414ccf54576a289735f10e3ee13
# wget -O pop_3_We_Don_t_Care.mp3 https://p.scdn.co/mp3-preview/893bca5eb7f90017390e26a88c584edd79492539?cid=577c3414ccf54576a289735f10e3ee13
# wget -O pop_4_Location.mp3 https://p.scdn.co/mp3-preview/d50dfb78af7cb29f6363ba1a0d2cbdd707ee137c?cid=577c3414ccf54576a289735f10e3ee13
# wget -O pop_5_Superheroes.mp3 https://p.scdn.co/mp3-preview/900dc33cad986d311dfbe7e87d7da0efdb921f98?cid=577c3414ccf54576a289735f10e3ee13
# wget -O pop_6_Dang!__feat._Anderson_.Paak_.mp3 https://p.scdn.co/mp3-preview/3e1d6ac23099c42068fff3f52c3fa8ddad86d36f?cid=577c3414ccf54576a289735f10e3ee13
# ...

# %%
track_name_list[33]
# Out:
# 'Cold Water (feat. Justin Bieber & MØ)'
