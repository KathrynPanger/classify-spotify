# %%
from spotipy.oauth2 import SpotifyClientCredentials
import matplotlib.pyplot as plt
import pandas as pd
import requests
import spotipy 
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import requests
import json

# %%
from config import cid
from config import secret
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
randoms = sp.recommendations(seed_genres=['blues', 'classical', 'country'], limit=100)

# %%
tracks_preview = []
tracks_id = []
tracks_name = []
tracks_artist = []
tracks_album = []

for album_ind in range(0, 100):
    tracks_preview.append(randoms['tracks'][album_ind]['preview_url'])
    tracks_id.append(randoms['tracks'][album_ind]['id'])
    tracks_name.append(randoms['tracks'][album_ind]['name'])
    tracks_artist.append(randoms['tracks'][album_ind]['artists'])
    
print(tracks_artist)
print(tracks_album)
# Out:
# [[{'external_urls': {'spotify': 'https://open.spotify.com/artist/1csBgT42N4pPPs1HJhxXIK'}, 'href': 'https://api.spotify.com/v1/artists/1csBgT42N4pPPs1HJhxXIK', 'id': '1csBgT42N4pPPs1HJhxXIK', 'name': 'Thomas Newman', 'type': 'artist', 'uri': 'spotify:artist:1csBgT42N4pPPs1HJhxXIK'}], [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2xAybx0jf6AnUy9I0kO0g9'}, 'href': 'https://api.spotify.com/v1/artists/2xAybx0jf6AnUy9I0kO0g9', 'id': '2xAybx0jf6AnUy9I0kO0g9', 'name': 'Murphy Elmore', 'type': 'artist', 'uri': 'spotify:artist:2xAybx0jf6AnUy9I0kO0g9'}], [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5fsDcuclIe8ZiBD5P787K1'}, 'href': 'https://api.spotify.com/v1/artists/5fsDcuclIe8ZiBD5P787K1', 'id': '5fsDcuclIe8ZiBD5P787K1', 'name': 'Stevie Ray Vaughan', 'type': 'artist', 'uri': 'spotify:artist:5fsDcuclIe8ZiBD5P787K1'}], [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1385hLNbrnbCJGokfH2ac2'}, 'href': 'https://api.spotify.com/v1/artists/1385hLNbrnbCJGokfH2ac2', 'id': '1385hLNbrnbCJGokfH2ac2', 'name': 'Franz Liszt', 'type': 'artist', 'uri': 'spotify:artist:1385hLNbrnbCJGokfH2ac2'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/5Kb0Qf13EyYtVJvzCdI9M7'}, 'href': 'https://api.spotify.com/v1/artists/5Kb0Qf13EyYtVJvzCdI9M7', 'id': '5Kb0Qf13EyYtVJvzCdI9M7', 'name': 'Jenő Jandó', 'type': 'artist', 'uri': 'spotify:artist:5Kb0Qf13EyYtVJvzCdI9M7'}], [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1yPwNaMwnx35H7uAaMfMfm'}, 'href': 'https://api.spotify.com/v1/artists/1yPwNaMwnx35H7uAaMfMfm', 'id': '1yPwNaMwnx35H7uAaMfMfm', 'name': 'Levon', 'type': 'artist', 'uri': 'spotify:artist:1yPwNaMwnx35H7uAaMfMfm'}], [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4y6J8jwRAwO4dssiSmN91R'}, 'href': 'https://api.spotify.com/v1/artists/4y6J8jwRAwO4dssiSmN91R', 'id': '4y6J8jwRAwO4dssiSmN91R', 'name': 'Muddy Waters', 'type': 'artist', 'uri': 'spotify:artist:4y6J8jwRAwO4dssiSmN91R'}], [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4TshyQDihSYXSWqvclXl3I'}, 'href': 'https://api.spotify.com/v1/artists/4TshyQDihSYXSWqvclXl3I', 'id': '4TshyQDihSYXSWqvclXl3I', 'name': 'Parmalee', 'type': 'artist', 'uri': 'spotify:artist:4TshyQDihSYXSWqvclXl3I'}], [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6nwh8AhPpbwOUnHZJWrHT6'}, 'href': 'https://api.spotify.com/v1/artists/6nwh8AhPpbwOUnHZJWrHT6', 'id': '6nwh8AhPpbwOUnHZJWrHT6', 'name': 'David Allan Coe', 'type': 'artist', 'uri': 'spotify:artist:6nwh8AhPpbwOUnHZJWrHT6'}], [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5fsDcuclIe8ZiBD5P787K1'}, 'href': 'https://api.spotify.com/v1/artists/5fsDcuclIe8ZiBD5P787K1', 'id': '5fsDcuclIe8ZiBD5P787K1', 'name': 'Stevie Ray Vaughan', 'type': 'artist', 'uri': 'spotify:artist:5fsDcuclIe8ZiBD5P787K1'}], [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eKWqnckwdIlSnjaYgIyxv'}, 'href': 'https://api.spotify.com/v1/artists/6eKWqnckwdIlSnjaYgIyxv', 'id': '6eKWqnckwdIlSnjaYgIyxv', 'name': 'Eli Young Band', 'type': 'artist', 'uri': 'spotify:artist:6eKWqnckwdIlSnjaYgIyxv'}], [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5aIqB5nVVvmFsvSdExz408'}, 'href': 'https://api.spotify.com/v1/artists/5aIqB5nVVvmFsvSdExz408', 'id': '5aIqB5nVVvmFsvSdExz408', 'name': 'Johann Sebastian Bach', 'type': 'artist', 'uri': 'spotify:artist:5aIqB5nVVvmFsvSdExz408'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/5Dl3HXZjG6ZOWT5cV375lk'}, 'href': 'https://api.spotify.com/v1/artists/5Dl3HXZjG6ZOWT5cV375lk', 'id': '5Dl3HXZjG6ZOWT5cV375lk', 'name': 'Yo-Yo Ma', 'type': 'artist', 'uri': 'spotify:artist:5Dl3HXZjG6ZOWT5cV375lk'}], [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Uff91EOsvd99rtAupatMP'}, 'href': 'https://api.spotify.com/v1/artists/1Uff91EOsvd99rtAupatMP', 'id': '1Uff91EOsvd99rtAupatMP', 'name': 'Claude Debussy', 'type': 'artist', 'uri': 'spotify:artist:1Uff91EOsvd99rtAupatMP'}, {'external_urls': {'spotify':  ...
# []

# %%
tracks_data = {'Track_ID':tracks_id, 
               'Track_Name':tracks_name, 
               'Track_Artist':tracks_artist, 
               'Preview_URL':tracks_preview}

tracks_df = pd.DataFrame(tracks_data)

tracks_df = tracks_df[tracks_df.Preview_URL != 'None']
tracks_df
# Out:
#                   Track_ID                                         Track_Name  \
# 0   5zMuzsE5kvd54FwraufeeK                     Shawshank Prison - Stoic Theme
# 1   48soTbO64fT2Xw3xxvAXY5                           Whoever Broke Your Heart
# 2   18PhtDBBYxE0vN4YvsZnMy                                    Scuttle Buttin'
# 3   6GzMz3s0K1YKwRVI36CgRx  Liebestraume, S541/R211 : No. 3: Nocturne in A...
# 4   01CNPn5mI7UZCtaOvg0Gmu                                 Give Up Your Heart
# ..                     ...                                                ...
# 95  6FmgSnILynpsvDmWTE9uPW                                      Johnny & June
# 96  7jxTdvTrVuqkuWwk0jXnVY                                   Love Struck Baby
# 97  77Z7XS4SNSN7EZve9nkPGP                                          Atlantico
# 98  5ZiU4oxQ6RxiEBIQpVa0mU                                       Rock Me Baby
# 99  7JQfc4yI4R8E4WOUYR7HD9                                        Fragment II
#
#                                          Track_Artist  \
# 0   [{'external_urls': {'spotify': 'https://open.s...
# 1   [{'external_urls': {'spotify': 'https://open.s...
# 2   [{'external_urls': {'spotify': 'https://open.s...
# 3   [{'external_urls': {'spotify': 'https://open.s...
# 4   [{'external_urls': {'spotify': 'https://open.s...
# ..                                                ...
# 95  [{'external_urls': {'spotify': 'https://open.s...
# 96  [{'external_urls': {'spotify': 'https://open.s...
# 97  [{'external_urls': {'spotify': 'https://open.s...
# 98  [{'external_urls': {'spotify': 'https://open.s...
# 99  [{'external_urls': {'spotify': 'https://open.s...
#
#                                           Preview_URL
# 0   https://p.scdn.co/mp3-preview/22238237168729f4...
# 1                                                None
# 2   https://p.scdn.co/mp3-preview/e017ebce54e66801...
# 3   https://p.scdn.co/mp3-preview/baef634095fc64d9...
# 4   https://p.scdn.co/mp3-preview/f58f4f75b8e22b34...
# ..                                                ...
# 95  https://p.scdn.co/mp3-preview/b65fe9caa28b20b2...
# 96  https://p.scdn.co/mp3-preview/1d61435ae48da513...
# 97  https://p.scdn.co/mp3-preview/d9ea42d9bdbdc7de...
# 98                                               None
# 99                                               None
#
# [100 rows x 4 columns]
