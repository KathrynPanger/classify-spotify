# %%
import pandas as pd

# %%
blues_df = pd.read_csv("blues/blues_machine_data.csv")
classical_df = pd.read_csv("classical/classical_machine_data.csv")
country_df = pd.read_csv("country/country_machine_data.csv")
# disco_df = pd.read_csv("")
# h_metal_df = pd.read_csv("")
# hiphip_df = pd.read_csv("")
# jazz_df = pd.read_csv("")
# pop_df = pd.read_csv("")
reggae_df = pd.read_csv("reggae/reggae_machine_data.csv")
rock_df = pd.read_csv("rock/rock_machine_data.csv")
reggae_df.head(10)
# Out:
#                                       Chroma Feature  \
# 0  [[0.54273897 0.50059573 0.78800814 ... 1.     ...
# 1  [[0.06635188 0.02899771 0.02442633 ... 0.06194...
# 2  [[0.78396491 0.9435171  0.77714013 ... 1.     ...
# 3  [[0.26045449 0.48321708 0.60594486 ... 0.39886...
# 4  [[0.61494001 0.14574306 0.07173546 ... 0.02920...
# 5  [[0.74254127 0.32249628 0.45519536 ... 0.11130...
# 6  [[0.20280451 0.3059004  0.31061829 ... 0.23535...
# 7  [[0.46629461 0.46156897 0.14965588 ... 0.14222...
# 8  [[0.36595344 0.30156862 0.34808273 ... 0.36901...
# 9  [[0.22715678 0.26301024 0.12319686 ... 0.06076...
#
#                                   Zero-Crossing Rate  \
# 0  [False False False False False False False Fal...
# 1  [False False False False False False False Fal...
# 2  [False False False False False  True  True Fal...
# 3  [False False False False False False False Fal...
# 4  [False False False False  True False  True Fal...
# 5  [False False False False False False False Fal...
# ...

# %%
blues_df = blues_df.head(100)
classical_df = classical_df.head(100)
country_df = country_df.head(100)
reggae_df = reggae_df.head(100)
rock_df = rock_df.head(100)

rock_df
# Out:
#                                        Chroma Feature  \
# 0   [[0.17819689 0.18785189 0.1063252  ... 0.34240...
# 1   [[0.68498164 0.59642253 0.59042702 ... 0.28854...
# 2   [[0.61784376 0.97323813 0.82880693 ... 0.47414...
# 3   [[0.85307955 0.5808911  0.37116136 ... 0.78683...
# 4   [[0.08885139 0.08371453 0.15189995 ... 0.06859...
# ..                                                ...
# 95  [[0.58779166 0.27056727 0.19674422 ... 1.     ...
# 96  [[0.14969204 0.14563017 0.11661472 ... 0.23444...
# 97  [[0.1574264  0.19312473 0.18104848 ... 0.03180...
# 98  [[0.36113007 0.38864845 0.46649247 ... 0.11049...
# 99  [[0.51119629 0.71380023 0.90824504 ... 0.27281...
#
#                                    Zero-Crossing Rate  \
# 0   [False False False False False False False Fal...
# 1   [False False False False False False False Fal...
# 2   [False False False False False False False Fal...
# 3   [False False False False False False False Fal...
# ...

# %%
blues_df.to_csv("../ML_dataframe/blues_machine_data.csv", index=False)
classical_df.to_csv("../ML_dataframe/classical_machine_data.csv", index=False)
country_df.to_csv("../ML_dataframe/country_machine_data.csv", index=False)
reggae_df.to_csv("../ML_dataframe/reggae_machine_data.csv", index=False)
rock_df.to_csv("../ML_dataframe/rock_machine_data.csv", index=False)

# %%
blues = pd.read_csv("../ML_dataframe/blues_machine_data.csv")
classical = pd.read_csv("../ML_dataframe/classical_machine_data.csv")
country = pd.read_csv("../ML_dataframe/country_machine_data.csv")
disco = pd.read_csv("../ML_dataframe/disco_machine_data.csv")
h_metal = pd.read_csv("../ML_dataframe/h_metal_machine_data.csv")
hiphip = pd.read_csv("../ML_dataframe/hiphop_machine_data.csv")
jazz = pd.read_csv("../ML_dataframe/jazz_machine_data.csv")
pop = pd.read_csv("../ML_dataframe/pop_machine_data.csv")
reggae = pd.read_csv("../ML_dataframe/reggae_machine_data.csv")
rock = pd.read_csv("../ML_dataframe/rock_machine_data.csv")

# %%
ml_df = pd.concat([blues, classical, country, disco, h_metal, hiphip, jazz, pop, reggae, rock], ignore_index=True)
ml_df
# Out:
#                                         Chroma Feature  \
# 0    [[0.30033454 0.34687778 0.5933234  ... 0.57389...
# 1    [[0.2430289  0.35798722 0.31239076 ... 0.12915...
# 2    [[0.57745107 0.70628192 0.44006866 ... 0.24273...
# 3    [[0.38471171 0.59468575 0.69452068 ... 1.     ...
# 4    [[0.21385682 0.34932139 0.33143732 ... 0.70961...
# ..                                                 ...
# 995  [[0.58779166 0.27056727 0.19674422 ... 1.     ...
# 996  [[0.14969204 0.14563017 0.11661472 ... 0.23444...
# 997  [[0.1574264  0.19312473 0.18104848 ... 0.03180...
# 998  [[0.36113007 0.38864845 0.46649247 ... 0.11049...
# 999  [[0.51119629 0.71380023 0.90824504 ... 0.27281...
#
#                                     Zero-Crossing Rate  \
# 0    [False False False False False False False Fal...
# 1    [False False False False False False False Fal...
# 2    [False False False False False False False Fal...
# 3    [False False False False False False False Fal...
# ...

# %%
ml_df.to_csv("../ML_dataframe/FINAL_ML_data.csv", index=False)
