# %%
from spotipy.oauth2 import SpotifyClientCredentials
import matplotlib.pyplot as plt
import pandas as pd
import requests
import spotipy 
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import requests
import json
import re
import requests
import urllib.request
import re
from bs4 import BeautifulSoup
import os

# %%
from config import cid
from config import secret
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
randoms = sp.recommendations(seed_genres=['classical'], limit=100)

# %%
tracks_preview = []
tracks_genre = []
tracks_name = []
tracks_id = []
tracks_artist = []
for album_ind in range(0, 100):
    tracks_genre.append(randoms['seeds'][0]['id'])
    tracks_name.append(randoms['tracks'][album_ind]['name'])
    tracks_id.append(randoms['tracks'][album_ind]['id'])
    tracks_preview.append(randoms['tracks'][album_ind]['preview_url'])

# %%
print(tracks_preview)
# Out:
# [None, None, 'https://p.scdn.co/mp3-preview/05d45d6387d5d91b8e3df231c7dd000d9b0d430e?cid=6410be731bfd4cf798c0e6e9a32589fc', 'https://p.scdn.co/mp3-preview/7c9e3856ff7f7289c38f14755a001654baec0d1b?cid=6410be731bfd4cf798c0e6e9a32589fc', 'https://p.scdn.co/mp3-preview/cb435b61645135c62e6cf45f2dc1dd8f0b797363?cid=6410be731bfd4cf798c0e6e9a32589fc', 'https://p.scdn.co/mp3-preview/8a98fd249be9843ee13597e678a338893e080277?cid=6410be731bfd4cf798c0e6e9a32589fc', 'https://p.scdn.co/mp3-preview/6717cafb0112a1af8cb629ef4aadcd8d77be3f3d?cid=6410be731bfd4cf798c0e6e9a32589fc', 'https://p.scdn.co/mp3-preview/9e14846e6f60448e7a07e5430dd8bc09d1858d5c?cid=6410be731bfd4cf798c0e6e9a32589fc', 'https://p.scdn.co/mp3-preview/df7dca793c70646b3f141118e8b52ef1588d84ce?cid=6410be731bfd4cf798c0e6e9a32589fc', 'https://p.scdn.co/mp3-preview/1016a9a6a2a1c9aab0921a63f1310b4f47729ab5?cid=6410be731bfd4cf798c0e6e9a32589fc', 'https://p.scdn.co/mp3-preview/e558143ee4bdb387667fedf764f5b11ffc3f9194?cid=6410be731bfd4cf798c0e
# ...

# %%
df5 = pd.DataFrame({'Genre':tracks_genre,'Track Name' : tracks_name, 'Track ID' : tracks_id, 'Preview_link' : tracks_preview})
df5.to_csv("classical/classical_dataframe_5.csv", index=False)

# %%
df1 = pd.read_csv("classical/classical_dataframe_1.csv")
df1.head()
# Out:
#        Genre                                         Track Name  \
# 0  classical  Dolly, Op. 56 (version for piano 4 hands): I. ...
# 1  classical                                     Noon Hill Wood
# 2  classical                               Ecce virgo concipiet
# 3  classical    Tzigane, M. 76 (Version for Violin & Orchestra)
# 4  classical  Concerto For Piano And Orchestra: 2. Presto - ...
#
#                  Track ID                                       Preview_link
# 0  1a7Z5exQ1nUBrCV4TV127U  https://p.scdn.co/mp3-preview/2d2e9d3771c8dccb...
# 1  3YgAJbmpO9d02lf7nZ6pIm                                                NaN
# 2  262HumMy5ZLcRgsP36CSyx  https://p.scdn.co/mp3-preview/02caeab5e558b9f5...
# 3  1OacCHsUQIAuUtlqv4I0c2  https://p.scdn.co/mp3-preview/cdd3bc0494cc4d9f...
# 4  0qkMYjXnxz91fEnnuMZNi0                                                NaN

# %%
df2 = pd.read_csv("classical/classical_dataframe_2.csv")
df2.head()
# Out:
#        Genre                                 Track Name  \
# 0  classical       Polovtsian Dances From "Prince Igor"
# 1  classical                                  Happiness
# 2  classical  Piano Sonata No.12 In F, K.332: 2. Adagio
# 3  classical                                   Prologue
# 4  classical                                    Opus 20
#
#                  Track ID                                       Preview_link
# 0  0PlTjNRzj6MkPfaLHNeZLZ                                                NaN
# 1  3BO3R8SLyb9cfSCgk1kXUl                                                NaN
# 2  0rkajHs0Kcw73nFDlKmuBk                                                NaN
# 3  6CeCOC2zx1qS8mQNYHe6IM  https://p.scdn.co/mp3-preview/97133f98bf1072ba...
# 4  4wwz5uVIGfB0DLgyUzQuRz                                                NaN

# %%
df3 = pd.read_csv("classical/classical_dataframe_3.csv")
df3.head()
# Out:
#        Genre                                         Track Name  \
# 0  classical  Hungarian Rhapsody No. 2 in C-Sharp Minor, S. ...
# 1  classical  Concerto Grosso in B-Flat Major, Op. 3, No. 2,...
# 2  classical                                      The Departure
# 3  classical                  Meditation: Méditation from Thaïs
# 4  classical  The Well-Tempered Clavier, Book 2, BWV 870-893...
#
#                  Track ID                                       Preview_link
# 0  7CIoJE0JfVFcmmUY3fFojH  https://p.scdn.co/mp3-preview/879c4458bd2dcac4...
# 1  5KGf2YteIJOZrpV98qQHiV  https://p.scdn.co/mp3-preview/9a17bee4cc0d3a4e...
# 2  7oTKvLjCe7db1UxsImGBwr                                                NaN
# 3  4Bub8omJzWHwVmvRA4WtP3                                                NaN
# 4  1nmeX39rjGxyaoSkPxSHwr  https://p.scdn.co/mp3-preview/fd4275fd7cdb2d1f...

# %%
df4 = pd.read_csv("classical/classical_dataframe_4.csv")
df4.head()
# Out:
#        Genre                                         Track Name  \
# 0  classical  Serenade in E Major for Strings, Op. 22: II. M...
# 1  classical  Cello Suite No. 1 in G Major, BWV 1007: I. Pré...
# 2  classical                                     Pavane, Op. 50
# 3  classical             Lincolnshire Posy: II. Horkstow Grange
# 4  classical  Piano Concerto No. 2 in D Minor, Op. 40, MWV O...
#
#                  Track ID                                       Preview_link
# 0  6HGzj1FMXVBAi2AtBCbhCQ                                                NaN
# 1  17i5jLpzndlQhbS4SrTd0B  https://p.scdn.co/mp3-preview/36fd583012498075...
# 2  2oqgnxjyNYItifLYl9MzaW  https://p.scdn.co/mp3-preview/d87cd7b90f740296...
# 3  6FwkSITKGSBNIpzdMDSgMR  https://p.scdn.co/mp3-preview/628c0996e87899c3...
# 4  6515L0Iaaah4YZUJubjfPS  https://p.scdn.co/mp3-preview/01f872b71316d103...

# %%
df5 = pd.read_csv("classical/classical_dataframe_5.csv")
df5.head()
# Out:
#        Genre                                         Track Name  \
# 0  classical  Tchaikovsky: Swan Lake, Op. 20, Act 2: No. 13 ...
# 1  classical                                      Þú ert jörðin
# 2  classical      Má vlast (My Country): No. 2, Vltava [Moldau]
# 3  classical  Violin Concerto in D Minor: Violin Concerto in...
# 4  classical                                    Metamorphosis 2
#
#                  Track ID                                       Preview_link
# 0  38iCfXPXqyeEHsNtlxjtSG                                                NaN
# 1  4zo9nVH8uBk5DnUa92ogWn                                                NaN
# 2  0P3TUNfXfhdJ4rgdZAUL6i  https://p.scdn.co/mp3-preview/05d45d6387d5d91b...
# 3  4nUkv8opB4P7e4fCzFU8ZW  https://p.scdn.co/mp3-preview/7c9e3856ff7f7289...
# 4  7uTyDwZOpODAIIWpkyX678  https://p.scdn.co/mp3-preview/cb435b61645135c6...

# %%
final_df = pd.concat([df1, df2, df3, df4, df5], ignore_index=True)
final_df
# Out:
#          Genre                                         Track Name  \
# 0    classical  Dolly, Op. 56 (version for piano 4 hands): I. ...
# 1    classical                                     Noon Hill Wood
# 2    classical                               Ecce virgo concipiet
# 3    classical    Tzigane, M. 76 (Version for Violin & Orchestra)
# 4    classical  Concerto For Piano And Orchestra: 2. Presto - ...
# ..         ...                                                ...
# 495  classical          Rhapsody on Moldavian Themes Op. 47 No. 3
# 496  classical  Prokofiev: Cinderella, Op. 87, Act 3: No. 42, ...
# 497  classical                 In the Beginning,There Was Nothing
# 498  classical      Touch Her Soft Lips and Part (From "Henry V")
# 499  classical                                    Capriccio primo
#
#                    Track ID                                       Preview_link
# 0    1a7Z5exQ1nUBrCV4TV127U  https://p.scdn.co/mp3-preview/2d2e9d3771c8dccb...
# ...

# %%
final_df = final_df.dropna(how='any')
final_df = final_df.drop_duplicates(subset=['Track ID'], keep='last')
final_df.reset_index()
final_df.to_csv("classical/classical.csv", index=False)

# %%
blues = pd.read_csv("classical/classical.csv")
blues
# Out:
#          Genre                                         Track Name  \
# 0    classical                               Ecce virgo concipiet
# 1    classical     L'apprenti sorcier (The Sorcerer's Apprentice)
# 2    classical  Prokofiev: Romeo and Juliet, Op. 64, Act 1: No...
# 3    classical  Monteverdi: L'incoronazione di Poppea, SV 308,...
# 4    classical  Pomp and Circumstance, Op. 39: No. 1, March in...
# ..         ...                                                ...
# 188  classical          Rhapsody on Moldavian Themes Op. 47 No. 3
# 189  classical  Prokofiev: Cinderella, Op. 87, Act 3: No. 42, ...
# 190  classical                 In the Beginning,There Was Nothing
# 191  classical      Touch Her Soft Lips and Part (From "Henry V")
# 192  classical                                    Capriccio primo
#
#                    Track ID                                       Preview_link
# 0    262HumMy5ZLcRgsP36CSyx  https://p.scdn.co/mp3-preview/02caeab5e558b9f5...
# ...

# %%
preview_list = blues['Preview_link'].tolist()
print(preview_list)
genre_list = blues['Genre'].tolist()
print(genre_list)
track_name_list = blues['Track Name'].tolist()
print(track_name_list)
# Out:
# ['https://p.scdn.co/mp3-preview/02caeab5e558b9f5ed7311809d95bd5743af0ee7?cid=6410be731bfd4cf798c0e6e9a32589fc', 'https://p.scdn.co/mp3-preview/9b5feeb2109377cb3e73abf995d724a6623cd02d?cid=6410be731bfd4cf798c0e6e9a32589fc', 'https://p.scdn.co/mp3-preview/2db99f3aeec5ecae904be3a075fe3ad79e8fd21d?cid=6410be731bfd4cf798c0e6e9a32589fc', 'https://p.scdn.co/mp3-preview/6b2cf713e419b4b9b553cc69aa65f99c86ef5e13?cid=6410be731bfd4cf798c0e6e9a32589fc', 'https://p.scdn.co/mp3-preview/c692a3670d7a16473204693266b462284b38590b?cid=6410be731bfd4cf798c0e6e9a32589fc', 'https://p.scdn.co/mp3-preview/3c61cee9ea17928cf923c706e7e42adac4f478c5?cid=6410be731bfd4cf798c0e6e9a32589fc', 'https://p.scdn.co/mp3-preview/6c17a663db4f57473e6b8d0e9a9bf92b6ea26373?cid=6410be731bfd4cf798c0e6e9a32589fc', 'https://p.scdn.co/mp3-preview/3df4c80b90bb67b5fbe0cc68ac6ac6cf6bc3285c?cid=6410be731bfd4cf798c0e6e9a32589fc', 'https://p.scdn.co/mp3-preview/28214cb9faf22a945e117317749088cd890eb18a?cid=6410be731bfd4cf798c0e6e9a32589fc'
# ...

# %%
for n, a_link in enumerate(preview_list):
    try:
        os.chdir('C:/Users/caitc/OneDrive/Desktop/DATA_BC/Homework/final-project/caitlin/classical/mp3s')
        track_name = track_name_list[n].replace(' ', '_')
        track_name = track_name.replace('""', "''")
        track_name = track_name.replace("'", '_')
        track_name = track_name.replace('(', '_')
        track_name = track_name.replace(')', '_')
        track_name = track_name.replace('&', '_')
        track_name = track_name.replace('-', '_')
        track_name = track_name.replace('/', '_')
        track_name = track_name.replace(':', '_')
        track_name = track_name.replace(',', '_')
        track_name = track_name.replace('.', '_')
        a_output = genre_list[n]+'_'+str(n)+'_'+ track_name +'.mp3'
        #cmd = "curl -O %s %s" % (a_output, a_link)
        r = requests.get(a_link)
        with open(a_output,'wb') as f: 
            f.write(r.content)
        print(a_link)
        print(a_output)
        #os.system(cmd)
    except:
        print("bummer")
# Out:
# https://p.scdn.co/mp3-preview/02caeab5e558b9f5ed7311809d95bd5743af0ee7?cid=6410be731bfd4cf798c0e6e9a32589fc
# classical_0_Ecce_virgo_concipiet.mp3
# https://p.scdn.co/mp3-preview/9b5feeb2109377cb3e73abf995d724a6623cd02d?cid=6410be731bfd4cf798c0e6e9a32589fc
# classical_1_L_apprenti_sorcier__The_Sorcerer_s_Apprentice_.mp3
# https://p.scdn.co/mp3-preview/2db99f3aeec5ecae904be3a075fe3ad79e8fd21d?cid=6410be731bfd4cf798c0e6e9a32589fc
# classical_2_Prokofiev__Romeo_and_Juliet__Op__64__Act_1__No__13__Dance_of_the_Knights__Complete_Ballet_.mp3
# bummer
# https://p.scdn.co/mp3-preview/c692a3670d7a16473204693266b462284b38590b?cid=6410be731bfd4cf798c0e6e9a32589fc
# classical_4_Pomp_and_Circumstance__Op__39__No__1__March_in_D_Major.mp3
# bummer
# https://p.scdn.co/mp3-preview/6c17a663db4f57473e6b8d0e9a9bf92b6ea26373?cid=6410be731bfd4cf798c0e6e9a32589fc
# classical_6_Oboe_Concerto__H__353__I__Moderato.mp3
# ...
