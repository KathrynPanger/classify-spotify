# %%
from spotipy.oauth2 import SpotifyClientCredentials
import matplotlib.pyplot as plt
import pandas as pd
import requests
import spotipy 
from spotipy.oauth2 import SpotifyClientCredentials
import requests
import json
import re
import requests
import urllib.request
import re
from bs4 import BeautifulSoup
import os

# %%
from config import cid
from config import secret
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
dataframe_1=pd.read_csv("hiphop1.csv")
dataframe_1.head()
# Out:
#                  Track_ID                                         Track_Name  \
# 0  0Altlm3kLPob56k2qqR4i2                                Money and the Power
# 1  67qn3OtziLlpOtVZ22EiQ4                  Smoke A Nigga (feat. Wiz Khalifa)
# 2  6SI4JD7iyQ0rrudhCNtMv0  Ice Cream (feat. Ghostface Killah, Method Man ...
# 3  1t4pPnbkOjzoA5RvsDjvUU                                      1999 WILDFIRE
# 4  6fwdbPMwP1zVStm8FybmkO                                   X (feat. Future)
#
#                                         Track_Artist  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
# 1  [{'external_urls': {'spotify': 'https://open.s...
# 2  [{'external_urls': {'spotify': 'https://open.s...
# 3  [{'external_urls': {'spotify': 'https://open.s...
# 4  [{'external_urls': {'spotify': 'https://open.s...
#
#                                          Preview_URL
# 0  https://p.scdn.co/mp3-preview/fa3cfc2b25fb07b5...
# 1  https://p.scdn.co/mp3-preview/0958ee470269059d...
# ...

# %%
dataframe_2=pd.read_csv("hiphop2.csv")
dataframe_2.head()
# Out:
#                  Track_ID                                        Track_Name  \
# 0  1HOUzEsetdIPSpAgRPhZQt                               Nobody Else but You
# 1  6jBCehpNMkwFVF3dz4nLIW                                       It's Tricky
# 2  53MHr9cjIlwet0mpmqNvjC  Go Off (with Lil Uzi Vert, Quavo & Travis Scott)
# 3  5n5uyFpfopa4mNdSN0gTaH                                             Wing$
# 4  0msneWUDfYKAGrifwEDhtl                             San Francisco Knights
#
#                                         Track_Artist  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
# 1  [{'external_urls': {'spotify': 'https://open.s...
# 2  [{'external_urls': {'spotify': 'https://open.s...
# 3  [{'external_urls': {'spotify': 'https://open.s...
# 4  [{'external_urls': {'spotify': 'https://open.s...
#
#                                          Preview_URL
# 0  https://p.scdn.co/mp3-preview/089d35c5f1e8b17e...
# 1  https://p.scdn.co/mp3-preview/cb0e687379eccb80...
# ...

# %%
dataframe_3 = pd.read_csv("hiphop3.csv")
dataframe_3.head()
# Out:
#                  Track_ID                  Track_Name  \
# 0  5fu9WzCJm7cKoU0zUrCfi3                        Jump
# 1  5tc5fqSM2rwgcwGcJUx8U1        Sippin On Some Syrup
# 2  49VzL5oBsUICN7U34T98b9  Instinct (feat. MadeinTYO)
# 3  5PIfH6BzcmH04RDmtzF0BN               Outside Today
# 4  7KZ5MMVgBVox9ycroB2UrI                    CAROUSEL
#
#                                         Track_Artist  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
# 1  [{'external_urls': {'spotify': 'https://open.s...
# 2  [{'external_urls': {'spotify': 'https://open.s...
# 3  [{'external_urls': {'spotify': 'https://open.s...
# 4  [{'external_urls': {'spotify': 'https://open.s...
#
#                                          Preview_URL
# 0  https://p.scdn.co/mp3-preview/3c89b07342cdb8da...
# 1  https://p.scdn.co/mp3-preview/ea09b97b9cb420d7...
# 2  https://p.scdn.co/mp3-preview/763e76af405c851d...
# 3  https://p.scdn.co/mp3-preview/e862d38519014ce8...
# ...

# %%
dataframe_4 = pd.read_csv("hiphop4.csv")
dataframe_4.head()
# Out:
#                  Track_ID     Track_Name  \
# 0  1t4pPnbkOjzoA5RvsDjvUU  1999 WILDFIRE
# 1  6BbINUfGabVyiNFJpQXn3x         Wicked
# 2  6JI5wNWYdBw68GZjOMmgK5      Put It On
# 3  1psC5iHzQxaTMZ5dWGfM6I          Juice
# 4  422lAAWQO9TqL1LxIPdhOn         Random
#
#                                         Track_Artist  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
# 1  [{'external_urls': {'spotify': 'https://open.s...
# 2  [{'external_urls': {'spotify': 'https://open.s...
# 3  [{'external_urls': {'spotify': 'https://open.s...
# 4  [{'external_urls': {'spotify': 'https://open.s...
#
#                                          Preview_URL
# 0  https://p.scdn.co/mp3-preview/43b8aeb423c5f954...
# 1  https://p.scdn.co/mp3-preview/f4e084bf3a27dc53...
# 2  https://p.scdn.co/mp3-preview/0b97d437197b7a08...
# 3  https://p.scdn.co/mp3-preview/0789909d666ea1d2...
# 4  https://p.scdn.co/mp3-preview/104b3d3ff431f9d7...

# %%
dataframe_5 = pd.read_csv("hiphop5.csv")
dataframe_5.head()
# Out:
#                  Track_ID               Track_Name  \
# 0  1iuljeYz6ZG3GTJOZZkoer               RGF Island
# 1  7LAhKXDNWwq3CmnFP3UIOP                Nightmare
# 2  5fu9WzCJm7cKoU0zUrCfi3                     Jump
# 3  1IAzD1muglOxOcPbUHs70R        Whatever You Like
# 4  0rBMP6VVGRgwnzZCLpijyl  Canal St. (feat. Bones)
#
#                                         Track_Artist  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
# 1  [{'external_urls': {'spotify': 'https://open.s...
# 2  [{'external_urls': {'spotify': 'https://open.s...
# 3  [{'external_urls': {'spotify': 'https://open.s...
# 4  [{'external_urls': {'spotify': 'https://open.s...
#
#                                          Preview_URL
# 0  https://p.scdn.co/mp3-preview/093068d8d4c6966b...
# 1  https://p.scdn.co/mp3-preview/fe5919c872201c66...
# 2  https://p.scdn.co/mp3-preview/3c89b07342cdb8da...
# 3  https://p.scdn.co/mp3-preview/c82678be83d118b5...
# 4  https://p.scdn.co/mp3-preview/bc4c3f41e7b0dc36...

# %%
dataframe_6 = pd.read_csv("hiphop6.csv")
dataframe_6
# Out:
#                   Track_ID                                         Track_Name  \
# 0   34oWbFBfGEElvgO0a5c9V4                                        No Flockin'
# 1   0shK5iZQppbHPQYiy60xs9                                         Rosa Parks
# 2   5uQOauh47VFt3B2kV9kRXw                                            My Shit
# 3   422lAAWQO9TqL1LxIPdhOn                                             Random
# 4   1iuljeYz6ZG3GTJOZZkoer                                         RGF Island
# 5   0wSeTpuEBS5uloIJ9tGhFi                          Hop Out (feat. A$AP Ferg)
# 6   0WQcnrsEqrY2e5nexGe3HX  Walk On Water (feat. A$AP Twelvyy, A$AP Ant, A...
# 7   5tRmoZRoupvMYPV1oezFrH                                                  X
# 8   7lAK3oHbfEnvUQWosrMMpR                                           YOSEMITE
# 9   4UNhyW0R7qylxrF6Z0q2Tb                                       Freek-A-Leek
# 10  4KaIJ1FWXUoAAnOts1YWjD           Prayers Up (feat. Travis Scott & A-Trak)
# ...

# %%
dataframe_7 = pd.read_csv("hiphop7.csv")
dataframe_7.head()
# Out:
#                  Track_ID                       Track_Name  \
# 0  0wSeTpuEBS5uloIJ9tGhFi        Hop Out (feat. A$AP Ferg)
# 1  3TXy6nchgKeYlVwOKNk9lE                        100 Shots
# 2  0dIoGTQXDh1wVnhIiSyYEa  Bartier Cardi (feat. 21 Savage)
# 3  7lAK3oHbfEnvUQWosrMMpR                         YOSEMITE
# 4  6BbINUfGabVyiNFJpQXn3x                           Wicked
#
#                                         Track_Artist  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
# 1  [{'external_urls': {'spotify': 'https://open.s...
# 2  [{'external_urls': {'spotify': 'https://open.s...
# 3  [{'external_urls': {'spotify': 'https://open.s...
# 4  [{'external_urls': {'spotify': 'https://open.s...
#
#                                          Preview_URL
# 0  https://p.scdn.co/mp3-preview/dbbe8f54cbbe3b93...
# 1  https://p.scdn.co/mp3-preview/f865f442a737b1dc...
# 2  https://p.scdn.co/mp3-preview/d7287b5aa682a642...
# 3  https://p.scdn.co/mp3-preview/93e6cdc0f8d46ff0...
# ...

# %%
final_df = pd.concat([dataframe_1, dataframe_2, dataframe_3, dataframe_4, dataframe_5,dataframe_6,dataframe_7])
final_df["Genre"] = "hiphop"
final_df
# Out:
#                   Track_ID                                         Track_Name  \
# 0   0Altlm3kLPob56k2qqR4i2                                Money and the Power
# 1   67qn3OtziLlpOtVZ22EiQ4                  Smoke A Nigga (feat. Wiz Khalifa)
# 2   6SI4JD7iyQ0rrudhCNtMv0  Ice Cream (feat. Ghostface Killah, Method Man ...
# 3   1t4pPnbkOjzoA5RvsDjvUU                                      1999 WILDFIRE
# 4   6fwdbPMwP1zVStm8FybmkO                                   X (feat. Future)
# ..                     ...                                                ...
# 39  0I0wn4G67txQwENcmRH3d6                                        Caribou Lou
# 40  6tZmrNnFao9ofNviYqJwOH  UP! (feat. Chris Brown, Pleasure P) (R&B Remix...
# 41  0CAfXk7DXMnon4gLudAp7J                                 Low (feat. T-Pain)
# 42  5YTM7OgQDt9EJAYcfHLniJ                                         Award Tour
# 43  7IhsLJMqdxoo7YAZjaSMru                                      Dead And Gone
#
# ...

# %%
#final_h_metal_merge_df = final_df.dropna(how = 'any')
disco_final_df = final_df.drop_duplicates()
disco_final_df.to_csv("disco_clean.csv", index=False)

# %%
clean_disco = pd.read_csv("disco_clean.csv")
clean_disco
# Out:
#                    Track_ID  \
# 0    0Altlm3kLPob56k2qqR4i2
# 1    67qn3OtziLlpOtVZ22EiQ4
# 2    6SI4JD7iyQ0rrudhCNtMv0
# 3    1t4pPnbkOjzoA5RvsDjvUU
# 4    6fwdbPMwP1zVStm8FybmkO
# ..                      ...
# 178  0I0wn4G67txQwENcmRH3d6
# 179  6tZmrNnFao9ofNviYqJwOH
# 180  0CAfXk7DXMnon4gLudAp7J
# 181  5YTM7OgQDt9EJAYcfHLniJ
# 182  7IhsLJMqdxoo7YAZjaSMru
#
#                                             Track_Name  \
# 0                                  Money and the Power
# 1                    Smoke A Nigga (feat. Wiz Khalifa)
# 2    Ice Cream (feat. Ghostface Killah, Method Man ...
# 3                                        1999 WILDFIRE
# 4                                     X (feat. Future)
# ..                                                 ...
# 178                                        Caribou Lou
# 179  UP! (feat. Chris Brown, Pleasure P) (R&B Remix...
# 180                                 Low (feat. T-Pain)
# 181                                         Award Tour
# ...

# %%
preview_list = clean_disco['Preview_URL'].tolist()
print(preview_list)
genre_list = clean_disco['Genre'].tolist()
print(genre_list)
track_name_list = clean_disco['Track_Name'].tolist()
print(track_name_list)
# Out:
# ['https://p.scdn.co/mp3-preview/fa3cfc2b25fb07b5baeb668cb526c519c04c5811?cid=57daa17ab8e544dcab420c4b154c56d9', 'https://p.scdn.co/mp3-preview/0958ee470269059d2899803d27ae2a3e8694a3c3?cid=57daa17ab8e544dcab420c4b154c56d9', 'https://p.scdn.co/mp3-preview/ccdc7b9141911228e4f0794e90e95616739db7e0?cid=57daa17ab8e544dcab420c4b154c56d9', 'https://p.scdn.co/mp3-preview/43b8aeb423c5f954404a3f54dba0126711ed8ddd?cid=57daa17ab8e544dcab420c4b154c56d9', 'https://p.scdn.co/mp3-preview/378ccd78be223f579b885d1f1195d29948514f9f?cid=57daa17ab8e544dcab420c4b154c56d9', 'https://p.scdn.co/mp3-preview/0347d93ed9de9904c5a4d228902c54c53181b33f?cid=57daa17ab8e544dcab420c4b154c56d9', 'https://p.scdn.co/mp3-preview/20b453e9c63f9b0789a50f9048d6a9a7c43ef615?cid=57daa17ab8e544dcab420c4b154c56d9', 'https://p.scdn.co/mp3-preview/b47bb06b997c0642dfa89b8803de1755d0a6f4de?cid=57daa17ab8e544dcab420c4b154c56d9', 'https://p.scdn.co/mp3-preview/c2947366a2f4f7e9002a4a0bf1df0c0f337043f6?cid=57daa17ab8e544dcab420c4b154c56d9'
# ...

# %%
#os.chdir('/Users/heesungshim/Desktop/2_Homework_BTC/final_group_project/heavy_metal/heavy_metal_mp3')


for n, a_link in enumerate(preview_list):
    try:
        os.chdir('/Users/sacst/Desktop/Data_Analytics/classify-spotify/Seth/hiphop/hiphop_mp3')
        track_name = track_name_list[n].replace(' ', '_')
        track_name = track_name.replace('""', "''")
        track_name = track_name.replace("'", '_')
        track_name = track_name.replace('(', '_')
        track_name = track_name.replace(')', '_')
        track_name = track_name.replace('&', '_')
        track_name = track_name.replace('-', '_')
        track_name = track_name.replace('/', '_')
        a_output = genre_list[n]+'_'+str(n)+'_'+ track_name +'.mp3'
        #cmd = "curl -O %s %s" % (a_output, a_link)
        r = requests.get(a_link)
        with open(a_output,'wb') as f: 
            f.write(r.content)
        print(a_link)
        print(a_output)
        #os.system(cmd)
    except:
        print("bummer")
# Out:
# https://p.scdn.co/mp3-preview/fa3cfc2b25fb07b5baeb668cb526c519c04c5811?cid=57daa17ab8e544dcab420c4b154c56d9
# hiphop_0_Money_and_the_Power.mp3
# https://p.scdn.co/mp3-preview/0958ee470269059d2899803d27ae2a3e8694a3c3?cid=57daa17ab8e544dcab420c4b154c56d9
# hiphop_1_Smoke_A_Nigga__feat._Wiz_Khalifa_.mp3
# https://p.scdn.co/mp3-preview/ccdc7b9141911228e4f0794e90e95616739db7e0?cid=57daa17ab8e544dcab420c4b154c56d9
# hiphop_2_Ice_Cream__feat._Ghostface_Killah,_Method_Man___Cappadonna_.mp3
# https://p.scdn.co/mp3-preview/43b8aeb423c5f954404a3f54dba0126711ed8ddd?cid=57daa17ab8e544dcab420c4b154c56d9
# hiphop_3_1999_WILDFIRE.mp3
# https://p.scdn.co/mp3-preview/378ccd78be223f579b885d1f1195d29948514f9f?cid=57daa17ab8e544dcab420c4b154c56d9
# hiphop_4_X__feat._Future_.mp3
# https://p.scdn.co/mp3-preview/0347d93ed9de9904c5a4d228902c54c53181b33f?cid=57daa17ab8e544dcab420c4b154c56d9
# hiphop_5_Sauce_It_Up.mp3
# ...

# %%
track_name_list[0]
genre_list[0]
# Out:
# 'hiphop'
