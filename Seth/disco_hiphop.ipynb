# %%
from spotipy.oauth2 import SpotifyClientCredentials
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import requests
import spotipy 
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import requests
import json

# %%
from config import cid
from config import secret
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
randoms = sp.recommendations(seed_genres=['hip-hop'], limit=100)

# %%
tracks_preview = []
tracks_id = []
tracks_name = []
tracks_artist = []
tracks_album = []

for album_ind in range(0, 100):
    tracks_preview.append(randoms['tracks'][album_ind]['preview_url'])
    tracks_id.append(randoms['tracks'][album_ind]['id'])
    tracks_name.append(randoms['tracks'][album_ind]['name'])
    tracks_artist.append(randoms['tracks'][album_ind]['artists'])
    
print(tracks_artist)
print(tracks_album)
# Out:
# [[{'external_urls': {'spotify': 'https://open.spotify.com/artist/4xRYI6VqpkE3UwrDrAZL8L'}, 'href': 'https://api.spotify.com/v1/artists/4xRYI6VqpkE3UwrDrAZL8L', 'id': '4xRYI6VqpkE3UwrDrAZL8L', 'name': 'Logic', 'type': 'artist', 'uri': 'spotify:artist:4xRYI6VqpkE3UwrDrAZL8L'}], [{'external_urls': {'spotify': 'https://open.spotify.com/artist/30fiiwr2EeZp1tAhzYCmyM'}, 'href': 'https://api.spotify.com/v1/artists/30fiiwr2EeZp1tAhzYCmyM', 'id': '30fiiwr2EeZp1tAhzYCmyM', 'name': 'Big L', 'type': 'artist', 'uri': 'spotify:artist:30fiiwr2EeZp1tAhzYCmyM'}], [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1RyvyyTE3xzB2ZywiAwp0i'}, 'href': 'https://api.spotify.com/v1/artists/1RyvyyTE3xzB2ZywiAwp0i', 'id': '1RyvyyTE3xzB2ZywiAwp0i', 'name': 'Future', 'type': 'artist', 'uri': 'spotify:artist:1RyvyyTE3xzB2ZywiAwp0i'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/50co4Is1HCEo8bhOyUWKpn'}, 'href': 'https://api.spotify.com/v1/artists/50co4Is1HCEo8bhOyUWKpn', 'id': '50co4Is1HCEo8bhOyUWKpn', 'name': 'Young Thug', 'type': 'artist', 'uri': 'spotify:artist:50co4Is1HCEo8bhOyUWKpn'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/4DdkRBBYG6Yk9Ka8tdJ9BW'}, 'href': 'https://api.spotify.com/v1/artists/4DdkRBBYG6Yk9Ka8tdJ9BW', 'id': '4DdkRBBYG6Yk9Ka8tdJ9BW', 'name': 'Offset', 'type': 'artist', 'uri': 'spotify:artist:4DdkRBBYG6Yk9Ka8tdJ9BW'}], [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1G9G7WwrXka3Z1r7aIDjI7'}, 'href': 'https://api.spotify.com/v1/artists/1G9G7WwrXka3Z1r7aIDjI7', 'id': '1G9G7WwrXka3Z1r7aIDjI7', 'name': 'OutKast', 'type': 'artist', 'uri': 'spotify:artist:1G9G7WwrXka3Z1r7aIDjI7'}], [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Z5jUyiNvFaqp0EVyLNf0p'}, 'href': 'https://api.spotify.com/v1/artists/5Z5jUyiNvFaqp0EVyLNf0p', 'id': '5Z5jUyiNvFaqp0EVyLNf0p', 'name': 'Futuristic', 'type': 'artist', 'uri': 'spotify:artist:5Z5jUyiNvFaqp0EVyLNf0p'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/1LrWZc2qPhRCHyr6XtpBxq'}, 'href': 'https://api.spotify.com/v1/artists/1LrWZc2qPhRCHyr6XtpBxq', 'id': '1LrWZc2qPhRCHyr6XtpBxq', 'name': 'Dizzy Wright', 'type': 'artist', 'uri': 'spotify:artist:1LrWZc2qPhRCHyr6XtpBxq'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/6wAO5FJZZ5PJoRBSpBic7M'}, 'href': 'https://api.spotify.com/v1/artists/6wAO5FJZZ5PJoRBSpBic7M', 'id': '6wAO5FJZZ5PJoRBSpBic7M', 'name': 'Layzie Bone', 'type': 'artist', 'uri': 'spotify:artist:6wAO5FJZZ5PJoRBSpBic7M'}], [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6y02TEMv71ArWB2qhIaQ5m'}, 'href': 'https://api.spotify.com/v1/artists/6y02TEMv71ArWB2qhIaQ5m', 'id': '6y02TEMv71ArWB2qhIaQ5m', 'name': 'Kaiydo', 'type': 'artist', 'uri': 'spotify:artist:6y02TEMv71ArWB2qhIaQ5m'}], [{'external_urls': {'spotify': 'https://open.spotify.com/artist/20qISvAhX20dpIbOOzGK3q'}, 'href': 'https://api.spotify.com/v1/artists/20qISvAhX20dpIbOOzGK3q', 'id': '20qISvAhX20dpIbOOzGK3q', 'name': 'Nas', 'type': 'artist', 'uri': 'spotify:artist:20qISvAhX20dpIbOOzGK3q'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/59wfkuBoNyhDMQGCljbUbA'}, 'href': 'https://api.spotify.com/v1/artists/59wfkuBoNyhDMQGCljbUbA', 'id': '59wfkuBoNyhDMQGCljbUbA', 'name': 'Diddy', 'type': 'artist', 'uri': 'spotify:artist:59wfkuBoNyhDMQGCljbUbA'}], [{'external_urls': {'spotify': 'https://open.spotify.com/artist/20sxb77xiYeusSH8cVdatc'}, 'href': 'https://api.spotify.com/v1/artists/20sxb77xiYeusSH8cVdatc', 'id': '20sxb77xiYeusSH8cVdatc', 'name': 'Meek Mill', 'type': 'artist', 'uri': 'spotify:artist:20sxb77xiYeusSH8cVdatc'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/4yLuE0l9rK7fqijTb7BPh9'}, 'href': 'https://api.spotify.com/v1/artists/4yLuE0l9rK7fqijTb7BPh9', 'id': '4yLuE0l9rK7fqijTb7BPh9', 'name': 'Sound M.O.B.', 'type': 'artist', 'uri': 'spotify:artist:4yLuE0l9rK7fqijTb7BPh9'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/2jku7tDXc6XoB6MO2hFuqg'}, 'href': 'https://api.s ...
# []

# %%
tracks_data = {'Track_ID':tracks_id, 
               'Track_Name':tracks_name, 
               'Track_Artist':tracks_artist, 
               'Preview_URL':tracks_preview}

tracks_df = pd.DataFrame(tracks_data)
#racks_df = tracks_df[tracks_df["Preview_URL"] != "Null"]
#tracks_df = tracks_df[tracks_df.Preview_URL != None]
tracks_df = tracks_df.replace(to_replace='None', value=np.nan).dropna()
#tracks_data.dropna()
tracks_df
# Out:
#                   Track_ID                                         Track_Name  \
# 1   04Rz403IY7QUqgfrTWX6OU                                       Da Graveyard
# 2   7r6LNJT2LqpLpEyZQJPygt                         Patek Water (feat. Offset)
# 3   0shK5iZQppbHPQYiy60xs9                                         Rosa Parks
# 4   4bTP7W5HEJYG0jR6EMfNka  I Guess I'll Smoke (feat. Dizzy Wright & Layzi...
# 5   0lpRp9KzzMbC0w1uiL7H7f                                        Fruit Punch
# 6   158DIbrVt4YbqNnWyRCS3P                     Hate Me Now (feat. Puff Daddy)
# 7   5J5PXmMdQ2nh1lZOal8KmK                           Litty (feat. Tory Lanez)
# 8   7LAhKXDNWwq3CmnFP3UIOP                                          Nightmare
# 9   6QJOEIPT8g3fjdFxibpy2F                                 Hood Took Me Under
# 12  49VzL5oBsUICN7U34T98b9                         Instinct (feat. MadeinTYO)
# 14  1Sgj10byiGzPpI2IrXSFEn                                    Protect Ya Neck
# 15  31bf9SEOppLU6lQ85d8om6  Ghetto Supastar (That is What You Are) (feat. ...
# 19  1tyjWMMINb9S0YBynTvJ7s    No Flag (feat. Nicki Minaj, 21 Savage & Offset)
# 1   [{'external_urls': {'spotify': 'https://open.s...
# 2   [{'external_urls': {'spotify': 'https://open.s...
# 3   [{'external_urls': {'spotify': 'https://open.s...
# 4   [{'external_urls': {'spotify': 'https://open.s...
# 5   [{'external_urls': {'spotify': 'https://open.s...
# 6   [{'external_urls': {'spotify': 'https://open.s...
# 7   [{'external_urls': {'spotify': 'https://open.s...
# 8   [{'external_urls': {'spotify': 'https://open.s...
# 9   [{'external_urls': {'spotify': 'https://open.s...
# 12  [{'external_urls': {'spotify': 'https://open.s...
# 14  [{'external_urls': {'spotify': 'https://open.s...
# 15  [{'external_urls': {'spotify': 'https://open.s...
# 19  [{'external_urls': {'spotify': 'https://open.s...
# 20  [{'external_urls': {'spotify': 'https://open.s...
# 21  [{'external_urls': {'spotify': 'https://open.s...
# 22  [{'external_urls': {'spotify': 'https://open.s...
# 23  [{'external_urls': {'spotify': 'https://open.s...
# 24  [{'external_urls': {'spotify': 'https://open.s...
# 28  [{'external_urls': {'spotify': 'https://open.s...
# 29  [{'external_urls': {'spotify': 'https://open.s...
# 30  [{'external_urls': {'spotify': 'https://open.s...
# 31  [{'external_urls': {'spotify': 'https://open.s...
# 32  [{'external_urls': {'spotify': 'https://open.s...
# 33  [{'external_urls': {'spotify': 'https://open.s...
# 36  [{'external_urls': {'spotify': 'https://open.s...
# 37  [{'external_urls': {'spotify': 'https://open.s...
# 38  [{'external_urls': {'spotify': 'https://open.s...
# 43  [{'external_urls': {'spotify': 'https://open.s...
# 44  [{'external_urls': {'spotify': 'https://open.s...
# 46  [{'external_urls': {'spotify': 'https://open.s...
# 47  [{'external_urls': {'spotify': 'https://open.s...
# 56  [{'external_urls': {'spotify': 'https://open.s...
# 57  [{'external_urls': {'spotify': 'https://open.s...
# 58  [{'external_urls': {'spotify': 'https://open.s...
# 59  [{'external_urls': {'spotify': 'https://open.s...
# 60  [{'external_urls': {'spotify': 'https://open.s...
# 62  [{'external_urls': {'spotify': 'https://open.s...
# 64  [{'external_urls': {'spotify': 'https://open.s...
# 68  [{'external_urls': {'spotify': 'https://open.s...
# 70  [{'external_urls': {'spotify': 'https://open.s...
# 71  [{'external_urls': {'spotify': 'https://open.s...
# 72  [{'external_urls': {'spotify': 'https://open.s...
# 75  [{'external_urls': {'spotify': 'https://open.s...
# 79  [{'external_urls': {'spotify': 'https://open.s...
# 82  [{'external_urls': {'spotify': 'https://open.s...
# 84  [{'external_urls': {'spotify': 'https://open.s...
# 86  [{'external_urls': {'spotify': 'https://open.s...
# 87  [{'external_urls': {'spotify': 'https://open.s...
# 90  [{'external_urls': {'spotify': 'https://open.s...
# 92  [{'external_urls': {'spotify': 'https://open.s...
# 96  [{'external_urls': {'spotify': 'https://open.s...
# 98  [{'external_urls': {'spotify': 'https://open.s...
#
#                                           Preview_URL
# 1   https://p.scdn.co/mp3-preview/20933036c8216e6c...
# 2   https://p.scdn.co/mp3-preview/ab0d45ffc05e9043...
# 3   https://p.scdn.co/mp3-preview/e3dabbb4cb699225...
# 4   https://p.scdn.co/mp3-preview/940d626d07be5d25...
# 5   https://p.scdn.co/mp3-preview/db9e29e10bb75419...
# 6   https://p.scdn.co/mp3-preview/c8447a16cd136d28...
# 7   https://p.scdn.co/mp3-preview/de09047b7beeb7e6...
# 8   https://p.scdn.co/mp3-preview/fe5919c872201c66...
