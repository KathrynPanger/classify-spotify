# %%
from spotipy.oauth2 import SpotifyClientCredentials
import matplotlib.pyplot as plt
import pandas as pd
import requests
import spotipy 
from spotipy.oauth2 import SpotifyClientCredentials
import requests
import json
import re
import requests
import urllib.request
import re
from bs4 import BeautifulSoup
import os

# %%
from config import cid
from config import secret
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
dataframe_1=pd.read_csv("disco1.csv")
dataframe_1.head()
# Out:
#                  Track_ID                        Track_Name  \
# 0  6UjlpJhUqOQqv0hrb38IDI                   Best of My Love
# 1  6VBy3FLlKZOWV85xmAXmr8           Get Down Tonight - Edit
# 2  3bidbhpOYeV4knp8AIu8Xn  Can't Hold Us - feat. Ray Dalton
# 3  1uoFwurhS62GOfTz2AbjYJ              Spank - 12 " Version
# 4  7iuT6GbzCKoyNVhbLaendu                    Never Too Much
#
#                                         Track_Artist  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
# 1  [{'external_urls': {'spotify': 'https://open.s...
# 2  [{'external_urls': {'spotify': 'https://open.s...
# 3  [{'external_urls': {'spotify': 'https://open.s...
# 4  [{'external_urls': {'spotify': 'https://open.s...
#
#                                          Preview_URL
# 0  https://p.scdn.co/mp3-preview/e20c1aaa3a9cd065...
# 1  https://p.scdn.co/mp3-preview/348cfde96da68705...
# 2  https://p.scdn.co/mp3-preview/1f826380a449ec9a...
# 3  https://p.scdn.co/mp3-preview/57871b154196c34e...
# 4  https://p.scdn.co/mp3-preview/904c1a43730cccd3...

# %%
dataframe_2=pd.read_csv("disco2.csv")
dataframe_2.head()
# Out:
#                  Track_ID                       Track_Name  \
# 0  714hERk9U1W8FMYkoC83CO                   You Sexy Thing
# 1  3NcO4jGK1Opb5ea0mYLpxb                     Good Feeling
# 2  4rwpZEcnalkuhPyGkEdhu0  Scary Monsters and Nice Sprites
# 3  4Am5pqHBUfYhJqdURXx84F                     Shout It Out
# 4  5Z7ygHQo02SUrFmcgpwsKW            Wild Ones (feat. Sia)
#
#                                         Track_Artist  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
# 1  [{'external_urls': {'spotify': 'https://open.s...
# 2  [{'external_urls': {'spotify': 'https://open.s...
# 3  [{'external_urls': {'spotify': 'https://open.s...
# 4  [{'external_urls': {'spotify': 'https://open.s...
#
#                                          Preview_URL
# 0  https://p.scdn.co/mp3-preview/7017e809f2d2961c...
# 1  https://p.scdn.co/mp3-preview/9b7c873ffd4d9893...
# 2  https://p.scdn.co/mp3-preview/fd1cb014b2eb27e1...
# 3  https://p.scdn.co/mp3-preview/922a3d8564eb231d...
# 4  https://p.scdn.co/mp3-preview/c09599c6378ab14c...

# %%
dataframe_3 = pd.read_csv("disco3.csv")
dataframe_3.head()
# Out:
#                  Track_ID                        Track_Name  \
# 0  4Am5pqHBUfYhJqdURXx84F                      Shout It Out
# 1  2NVpYQqdraEcQwqT7GhUkh                      Ain't Nobody
# 2  2iblMMIgSznA464mNov7A8  Don't Stop the Party (feat. TJR)
# 3  6PtXobrqImYfnpIxNsJApa    Bad (feat. Vassy) - Radio Edit
# 4  352zfYbDFG8sxkmOAhVeuj       Under Control (feat. Hurts)
#
#                                         Track_Artist  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
# 1  [{'external_urls': {'spotify': 'https://open.s...
# 2  [{'external_urls': {'spotify': 'https://open.s...
# 3  [{'external_urls': {'spotify': 'https://open.s...
# 4  [{'external_urls': {'spotify': 'https://open.s...
#
#                                          Preview_URL
# 0  https://p.scdn.co/mp3-preview/922a3d8564eb231d...
# 1  https://p.scdn.co/mp3-preview/da3c4d60cefc078b...
# 2  https://p.scdn.co/mp3-preview/7fd27386664a7367...
# 3  https://p.scdn.co/mp3-preview/8ba977e7297a72f7...
# 4  https://p.scdn.co/mp3-preview/3878c6912e95d20a...

# %%
dataframe_4 = pd.read_csv("disco4.csv")
dataframe_4.head()
# Out:
#                  Track_ID                              Track_Name  \
# 0  07MHhfYd2Kkt2zFnqRZM1z               Boogie Shoes - 45 Version
# 1  62zFEHfAYl5kdHYOivj4BC  International Love (feat. Chris Brown)
# 2  3XVozq1aeqsJwpXrEZrDJ9                            Ice Ice Baby
# 3  24LS4lQShWyixJ0ZrJXfJ5    Sweet Nothing (feat. Florence Welch)
# 4  6T27IN7Ai94BeDv6PPCmoC          Turn Me On (feat. Nicki Minaj)
#
#                                         Track_Artist  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
# 1  [{'external_urls': {'spotify': 'https://open.s...
# 2  [{'external_urls': {'spotify': 'https://open.s...
# 3  [{'external_urls': {'spotify': 'https://open.s...
# 4  [{'external_urls': {'spotify': 'https://open.s...
#
#                                          Preview_URL
# 0  https://p.scdn.co/mp3-preview/c23dd5c75469c4d4...
# 1  https://p.scdn.co/mp3-preview/23235746b5a67425...
# 2  https://p.scdn.co/mp3-preview/6545dbe31d7d19eb...
# 3  https://p.scdn.co/mp3-preview/34ef2c315f140d22...
# 4  https://p.scdn.co/mp3-preview/83ca8ab672a0a2dc...

# %%
dataframe_5 = pd.read_csv("disco5.csv")
dataframe_5.head()
# Out:
#                  Track_ID                       Track_Name  \
# 0  5ChkMS8OtdzJeqyybCc9R5                      Billie Jean
# 1  714hERk9U1W8FMYkoC83CO                   You Sexy Thing
# 2  3UN6cIn3VIyg0z1LCuFSum        Without You (feat. Usher)
# 3  4OdA7oQSpNvUhdOcNJok0D  Love Come Down - Single Version
# 4  1wRHNlEjTmpaXv99BFAGnV  Got To Be Real - Single Version
#
#                                         Track_Artist  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
# 1  [{'external_urls': {'spotify': 'https://open.s...
# 2  [{'external_urls': {'spotify': 'https://open.s...
# 3  [{'external_urls': {'spotify': 'https://open.s...
# 4  [{'external_urls': {'spotify': 'https://open.s...
#
#                                          Preview_URL
# 0  https://p.scdn.co/mp3-preview/f504e6b8e0377713...
# 1  https://p.scdn.co/mp3-preview/7017e809f2d2961c...
# 2  https://p.scdn.co/mp3-preview/53e072ec1b741fd5...
# 3  https://p.scdn.co/mp3-preview/8e4e83d331d3154f...
# 4  https://p.scdn.co/mp3-preview/5316488d9a73562b...

# %%
dataframe_6 = pd.read_csv("disco6.csv")
dataframe_6
# Out:
#                   Track_ID                                       Track_Name  \
# 0   28285KFbyCq8sJofn58qlD                                       Love Train
# 1   6VBy3FLlKZOWV85xmAXmr8                          Get Down Tonight - Edit
# 2   3GGcwG519BTMdvMeFy7meT                                   Lady Marmalade
# 3   2goLsvvODILDzeeiT4dAoR                                          Believe
# 4   0TDLuuLlV54CkRRUOahJb4                             Titanium (feat. Sia)
# 5   714hERk9U1W8FMYkoC83CO                                   You Sexy Thing
# 6   2cZrrQMjB63c0iIugYH9zS                Rain Over Me (feat. Marc Anthony)
# 7   3WMbD1OyfKuwWDWMNbPQ4g                                       Daddy Cool
# 8   2gNAGt7gUiMkagkhIiDLPm                                      Dansa Pausa
# 9   2DX0WG5OGLQLaXb41Cq1IA                      I Will Survive - Remastered
# 10  1xN7BpTAWnZkuSLOtRP6Qc                        Euphoria - Single Version
# 11  6VRhkROS2SZHGlp0pxndbJ                          Bangarang (feat. Sirah)
# 12  3pf96IFggfQuT6Gafqx2rt                                            Sunny
# 13  2iblMMIgSznA464mNov7A8                 Don't Stop the Party (feat. TJR)
# 14  5Z7ygHQo02SUrFmcgpwsKW                            Wild Ones (feat. Sia)
# 15  1tJtx09XQnxaynZLOaTNfZ                                         Car Wash
# 16  1CmUZGtH29Kx36C1Hleqlz                         Thrift Shop (feat. Wanz)
# 17  4d2hD63oUGU3s7L66JD0BE                                      Dance Again
# 18  7KPr0YxECy4Q1k2F17Sa0Q                        Memories (feat. Kid Cudi)
# 19  1kAZhbcsXqfUjnVeqPywn2                    Danza Kuduro (feat. Don Omar)
# 20  7iuT6GbzCKoyNVhbLaendu                                   Never Too Much
# 21  33qw98yPnShEQMoF72ORUa                                          Amazing
# 22  3zrYNl1aMdFrQkcOjKVr5u                                            I Cry
# 23  717TY4sfgKQm4kFbYQIzgo                                            Toxic
# 24  7zpm7lTY2EZn7AfFm3mGg2                                    Lost in Music
# 25  5HOpkTTVcmZHnthgyxrIL8                 The Fox (What Does the Fox Say?)
# 26  6tsMC7YCLcQxr16O77fkoX     Little Bad Girl (feat. Taio Cruz & Ludacris)
# 27  1zHlj4dQ8ZAtrayhuDDmkY                             Timber (feat. Ke$ha)
# 28  24LS4lQShWyixJ0ZrJXfJ5             Sweet Nothing (feat. Florence Welch)
# 29  6vUqCD6WPsccXUEd9O9gJG                                       This Is It
# 30  2a1MrtxYybqFV1Ow8VJ1dW                      I Will Survive - Rerecorded
# 31  4msPRe3NEDVL6dsBcE7AhL                                 Get Down Tonight
# 32  5MuNxNox3zTanAFIO5KcTl                         He's the Greatest Dancer
# 33  1eJNe0mul5KtNv8Wnj18pR                                   I Love to Love
# 34  6VCj1ehtOIqOX9aTQlrD1O                                         Bad Luck
# 35  5J2UfqBylH8jDQZJnxby81                            Sean den förste Banan
# 36  0D2VYiRlBv43asKUgieZaM                               Jubel - Radio Edit
# 37  6HdM7gzXVgcpepv276raog                                     It's My Life
# 38  7723JnKU2R15Iv4T7OJrly                                       Funky Town
# 39  05SBRd4fXgn8FX7bf8BCAE          I Need Your Love (feat. Ellie Goulding)
# 40  16Cs9KsHzgunxaEfGrXysG        Play Hard (feat. Ne-Yo & Akon) - New Edit
# 41  3VZQshi4COChhXaz7cLP02  I Love It (feat. Charli XCX) - Original Version
# 42  0ZvLrvwzp0nBkfmtzL7XO1                 Relight My Fire - Single Version
# 43  7s25THrKz86DM225dOYwnr                                          Respect
# 44  07MHhfYd2Kkt2zFnqRZM1z                        Boogie Shoes - 45 Version
# 45  5ChkMS8OtdzJeqyybCc9R5                                      Billie Jean
#
#                                          Track_Artist  \
# 0   [{'external_urls': {'spotify': 'https://open.s...
# 1   [{'external_urls': {'spotify': 'https://open.s...
# 2   [{'external_urls': {'spotify': 'https://open.s...
# 3   [{'external_urls': {'spotify': 'https://open.s...
# 4   [{'external_urls': {'spotify': 'https://open.s...
# 5   [{'external_urls': {'spotify': 'https://open.s...
# 6   [{'external_urls': {'spotify': 'https://open.s...
# 7   [{'external_urls': {'spotify': 'https://open.s...
# 8   [{'external_urls': {'spotify': 'https://open.s...
# 9   [{'external_urls': {'spotify': 'https://open.s...
# 10  [{'external_urls': {'spotify': 'https://open.s...
# 11  [{'external_urls': {'spotify': 'https://open.s...
# 12  [{'external_urls': {'spotify': 'https://open.s...
# 13  [{'external_urls': {'spotify': 'https://open.s...
# 14  [{'external_urls': {'spotify': 'https://open.s...
# 15  [{'external_urls': {'spotify': 'https://open.s...
# 16  [{'external_urls': {'spotify': 'https://open.s...
# 17  [{'external_urls': {'spotify': 'https://open.s...
# 18  [{'external_urls': {'spotify': 'https://open.s...
# 19  [{'external_urls': {'spotify': 'https://open.s...
# 20  [{'external_urls': {'spotify': 'https://open.s...
# 21  [{'external_urls': {'spotify': 'https://open.s...
# 22  [{'external_urls': {'spotify': 'https://open.s...
# 23  [{'external_urls': {'spotify': 'https://open.s...
# 24  [{'external_urls': {'spotify': 'https://open.s...
# 25  [{'external_urls': {'spotify': 'https://open.s...
# 26  [{'external_urls': {'spotify': 'https://open.s...
# 27  [{'external_urls': {'spotify': 'https://open.s...
# 28  [{'external_urls': {'spotify': 'https://open.s...
# 29  [{'external_urls': {'spotify': 'https://open.s...
# 30  [{'external_urls': {'spotify': 'https://open.s...
# 31  [{'external_urls': {'spotify': 'https://open.s...
# 32  [{'external_urls': {'spotify': 'https://open.s...
# 33  [{'external_urls': {'spotify': 'https://open.s...
# 34  [{'external_urls': {'spotify': 'https://open.s...
# 35  [{'external_urls': {'spotify': 'https://open.s...
# 36  [{'external_urls': {'spotify': 'https://open.s...
# 37  [{'external_urls': {'spotify': 'https://open.s...
# 38  [{'external_urls': {'spotify': 'https://open.s...
# 39  [{'external_urls': {'spotify': 'https://open.s...
# 40  [{'external_urls': {'spotify': 'https://open.s...
# 41  [{'external_urls': {'spotify': 'https://open.s...
# 42  [{'external_urls': {'spotify': 'https://open.s...
# 43  [{'external_urls': {'spotify': 'https://open.s...
# 44  [{'external_urls': {'spotify': 'https://open.s...
# 45  [{'external_urls': {'spotify': 'https://open.s...
#
#                                           Preview_URL
# 0   https://p.scdn.co/mp3-preview/6a2c40a2caaaaea4...
# 1   https://p.scdn.co/mp3-preview/348cfde96da68705...
# 2   https://p.scdn.co/mp3-preview/da137cbab59ef54b...
# 3   https://p.scdn.co/mp3-preview/579967c91dc409b6...
# 4   https://p.scdn.co/mp3-preview/06392eaab5975806...
# 5   https://p.scdn.co/mp3-preview/7017e809f2d2961c...
# 6   https://p.scdn.co/mp3-preview/406c96692d6f572b...
# 7   https://p.scdn.co/mp3-preview/191db1a9fda30574...
# 8   https://p.scdn.co/mp3-preview/7872b49150e61748...
# 9   https://p.scdn.co/mp3-preview/136f43b54553a7ea...
# 10  https://p.scdn.co/mp3-preview/0a479cc2b321a6e1...
# 11  https://p.scdn.co/mp3-preview/569d7afebba42141...
# 12  https://p.scdn.co/mp3-preview/5665823591395cba...
# 13  https://p.scdn.co/mp3-preview/7fd27386664a7367...
# 14  https://p.scdn.co/mp3-preview/c09599c6378ab14c...
# 15  https://p.scdn.co/mp3-preview/7230a11dd762c2c6...
# 16  https://p.scdn.co/mp3-preview/26cdc03872031160...
# 17  https://p.scdn.co/mp3-preview/2d288b4a7117b800...
# 18  https://p.scdn.co/mp3-preview/9364e08b3d1452c0...
# 19  https://p.scdn.co/mp3-preview/de9358c4194d430a...
# 20  https://p.scdn.co/mp3-preview/904c1a43730cccd3...
# 21  https://p.scdn.co/mp3-preview/5654fbc1a6724446...
# 22  https://p.scdn.co/mp3-preview/83ecc26ad34e94df...
# 23  https://p.scdn.co/mp3-preview/54b4db0823ebada5...
# 24  https://p.scdn.co/mp3-preview/2b420bf751bbc59f...
# 25  https://p.scdn.co/mp3-preview/42f7a502c081b373...
# 26  https://p.scdn.co/mp3-preview/b53023c8c71950a8...
# 27  https://p.scdn.co/mp3-preview/ecb1639c58ceb631...
# 28  https://p.scdn.co/mp3-preview/34ef2c315f140d22...
# 29  https://p.scdn.co/mp3-preview/7c3d89b265334d62...
# 30  https://p.scdn.co/mp3-preview/0f5744013a9c7464...
# 31  https://p.scdn.co/mp3-preview/a4b1e550d564f7c6...
# 32  https://p.scdn.co/mp3-preview/1a0f32d036929246...
# 33  https://p.scdn.co/mp3-preview/fd124a31160c030e...
# 34  https://p.scdn.co/mp3-preview/92b45d276365409c...
# 35  https://p.scdn.co/mp3-preview/efb64c7d08ad4d0b...
# 36  https://p.scdn.co/mp3-preview/609d21d24ab7a92e...
# 37  https://p.scdn.co/mp3-preview/161554d92cc88e78...
# 38  https://p.scdn.co/mp3-preview/7378227189ebb06c...
# 39  https://p.scdn.co/mp3-preview/40c1150a43b8c93b...
# 40  https://p.scdn.co/mp3-preview/06a0e54f1729141c...
# 41  https://p.scdn.co/mp3-preview/53d0fca6eb2c0180...
# 42  https://p.scdn.co/mp3-preview/811c5fd1049e3ee9...
# 43  https://p.scdn.co/mp3-preview/b0d0b4ec89637792...
# 44  https://p.scdn.co/mp3-preview/c23dd5c75469c4d4...
# 45  https://p.scdn.co/mp3-preview/f504e6b8e0377713...

# %%
dataframe_7 = pd.read_csv("disco7.csv")
dataframe_7.head()
# Out:
#                  Track_ID                            Track_Name  \
# 0  1kAZhbcsXqfUjnVeqPywn2         Danza Kuduro (feat. Don Omar)
# 1  24LS4lQShWyixJ0ZrJXfJ5  Sweet Nothing (feat. Florence Welch)
# 2  6HdM7gzXVgcpepv276raog                          It's My Life
# 3  6UjlpJhUqOQqv0hrb38IDI                       Best of My Love
# 4  7gssYOCe03w6yC1JMjXiCN                        Instant Replay
#
#                                         Track_Artist  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
# 1  [{'external_urls': {'spotify': 'https://open.s...
# 2  [{'external_urls': {'spotify': 'https://open.s...
# 3  [{'external_urls': {'spotify': 'https://open.s...
# 4  [{'external_urls': {'spotify': 'https://open.s...
#
#                                          Preview_URL
# 0  https://p.scdn.co/mp3-preview/de9358c4194d430a...
# 1  https://p.scdn.co/mp3-preview/34ef2c315f140d22...
# 2  https://p.scdn.co/mp3-preview/161554d92cc88e78...
# 3  https://p.scdn.co/mp3-preview/e20c1aaa3a9cd065...
# 4  https://p.scdn.co/mp3-preview/9f146a1f91e2ee47...

# %%
final_df = pd.concat([dataframe_1, dataframe_2, dataframe_3, dataframe_4, dataframe_5,dataframe_6,dataframe_7])
final_df["Genre"] = "disco"
final_df
# Out:
#                   Track_ID                        Track_Name  \
# 0   6UjlpJhUqOQqv0hrb38IDI                   Best of My Love
# 1   6VBy3FLlKZOWV85xmAXmr8           Get Down Tonight - Edit
# 2   3bidbhpOYeV4knp8AIu8Xn  Can't Hold Us - feat. Ray Dalton
# 3   1uoFwurhS62GOfTz2AbjYJ              Spank - 12 " Version
# 4   7iuT6GbzCKoyNVhbLaendu                    Never Too Much
# ..                     ...                               ...
# 42  2CVqF1sLhwut4NiZxzNUnC   Sweet Dreams (Are Made of This)
# 43  7KPr0YxECy4Q1k2F17Sa0Q         Memories (feat. Kid Cudi)
# 44  6SKwQghsR8AISlxhcwyA9R                         Marry You
# 45  4msPRe3NEDVL6dsBcE7AhL                  Get Down Tonight
# 46  28285KFbyCq8sJofn58qlD                        Love Train
#
#                                          Track_Artist  \
# 0   [{'external_urls': {'spotify': 'https://open.s...
# 1   [{'external_urls': {'spotify': 'https://open.s...
# 2   [{'external_urls': {'spotify': 'https://open.s...
# 3   [{'external_urls': {'spotify': 'https://open.s...
# 4   [{'external_urls': {'spotify': 'https://open.s...
# ..                                                ...
# 42  [{'external_urls': {'spotify': 'https://open.s...
# 43  [{'external_urls': {'spotify': 'https://open.s...
# 44  [{'external_urls': {'spotify': 'https://open.s...
# 45  [{'external_urls': {'spotify': 'https://open.s...
# 46  [{'external_urls': {'spotify': 'https://open.s...
#
#                                           Preview_URL  Genre
# 0   https://p.scdn.co/mp3-preview/e20c1aaa3a9cd065...  disco
# 1   https://p.scdn.co/mp3-preview/348cfde96da68705...  disco
# 2   https://p.scdn.co/mp3-preview/1f826380a449ec9a...  disco
# 3   https://p.scdn.co/mp3-preview/57871b154196c34e...  disco
# 4   https://p.scdn.co/mp3-preview/904c1a43730cccd3...  disco
# ..                                                ...    ...
# 42  https://p.scdn.co/mp3-preview/42294fbcc0af128f...  disco
# 43  https://p.scdn.co/mp3-preview/9364e08b3d1452c0...  disco
# 44  https://p.scdn.co/mp3-preview/b50deda939ea2475...  disco
# 45  https://p.scdn.co/mp3-preview/a4b1e550d564f7c6...  disco
# 46  https://p.scdn.co/mp3-preview/6a2c40a2caaaaea4...  disco
#
# [304 rows x 5 columns]

# %%
#final_h_metal_merge_df = final_df.dropna(how = 'any')
disco_final_df = final_df.drop_duplicates()
disco_final_df.to_csv("disco_clean.csv", index=False)

# %%
clean_disco = pd.read_csv("disco_clean.csv")
clean_disco
# Out:
#                    Track_ID  \
# 0    6UjlpJhUqOQqv0hrb38IDI
# 1    6VBy3FLlKZOWV85xmAXmr8
# 2    3bidbhpOYeV4knp8AIu8Xn
# 3    1uoFwurhS62GOfTz2AbjYJ
# 4    7iuT6GbzCKoyNVhbLaendu
# ..                      ...
# 156  0CAfXk7DXMnon4gLudAp7J
# 157  1CLNWD0IK5YXc9KpTKaRF2
# 158  2wqaekenSQZm7hxQOYt8oE
# 159  2Foc5Q5nqNiosCNqttzHof
# 160  6SKwQghsR8AISlxhcwyA9R
#
#                                             Track_Name  \
# 0                                      Best of My Love
# 1                              Get Down Tonight - Edit
# 2                     Can't Hold Us - feat. Ray Dalton
# 3                                 Spank - 12 " Version
# 4                                       Never Too Much
# ..                                                 ...
# 156                                 Low (feat. T-Pain)
# 157                            Dance Little Lady Dance
# 158                                         Am I Wrong
# 159  Get Lucky (feat. Pharrell Williams & Nile Rodg...
# 160                                          Marry You
#
#                                           Track_Artist  \
# 0    [{'external_urls': {'spotify': 'https://open.s...
# 1    [{'external_urls': {'spotify': 'https://open.s...
# 2    [{'external_urls': {'spotify': 'https://open.s...
# 3    [{'external_urls': {'spotify': 'https://open.s...
# 4    [{'external_urls': {'spotify': 'https://open.s...
# ..                                                 ...
# 156  [{'external_urls': {'spotify': 'https://open.s...
# 157  [{'external_urls': {'spotify': 'https://open.s...
# 158  [{'external_urls': {'spotify': 'https://open.s...
# 159  [{'external_urls': {'spotify': 'https://open.s...
# 160  [{'external_urls': {'spotify': 'https://open.s...
#
#                                            Preview_URL  Genre
# 0    https://p.scdn.co/mp3-preview/e20c1aaa3a9cd065...  disco
# 1    https://p.scdn.co/mp3-preview/348cfde96da68705...  disco
IFA World Cup (TM) Song] (feat. Freshlyground)', 'The Fox (What Does the Fox Say?)', 'Boogie Shoes - 45 Version', 'Ice Ice Baby', 'Turn Me On (feat. Nicki Minaj)', 'The Love I Lost', "She Doesn't Mind", "It's My Life", 'Thinking of You', 'Down Under', 'Till the World Ends', 'Locked out of Heaven', 'Daddy Cool', 'T.S.O.P. (The Sound of Philadelphia) (feat. The Three Degrees)', 'Bangarang (feat. Sirah)', 'Titanium (feat. Sia)', 'Girls Just Want to Have Fun', "It's Raining Men", 'In The Club', 'Rain Over Me (feat. Marc Anthony)', "Rapper's Delight", 'Get Down Tonight', 'Prayer in C - Robin Schulz Radio Edit', 'Sean den förste Banan', 'Love Come Down - Single Version', 'Got To Be Real - Single Version', 'Vertigo/Relight My Fire', 'Cotton Eye Joe', 'One Way Ticket', 'Give It Up', 'Bad Luck', 'Copacabana (At the Copa) - Long Version', 'Everybody Dance - 12" Mix', 'Play Hard (feat. Ne-Yo & Akon) - New Edit', 'Copacabanana', 'Lady Marmalade', "I'm Every Woman", 'Tsunami', "We'll Be Coming Back (feat. Example)", 'Rather Be (feat. Jess Glynne)', 'When Love Takes Over (feat. Kelly Rowland)', 'Skyline', 'Där palmerna bor', "Don't Leave Me This Way", 'Boten Anna - Radio edit', 'Believe', 'Danza Kuduro (feat. Don Omar)', 'I Cry', 'Toxic', 'Lost in Music', 'This Is It', 'I Will Survive - Rerecorded', 'Respect', 'Instant Replay', 'Barbra Streisand -  ...

# %%
#os.chdir('/Users/heesungshim/Desktop/2_Homework_BTC/final_group_project/heavy_metal/heavy_metal_mp3')

try:
    for n, a_link in enumerate(preview_list):
        os.chdir('/Users/sacst/Desktop/Data_Analytics/classify-spotify/Seth/disco/disco_mp3')
        track_name = track_name_list[n].replace(' ', '_')
        track_name = track_name.replace('""', "''")
        track_name = track_name.replace("'", '_')
        track_name = track_name.replace('(', '_')
        track_name = track_name.replace(')', '_')
        track_name = track_name.replace('&', '_')
        track_name = track_name.replace('-', '_')
        track_name = track_name.replace('/', '_')
        a_output = genre_list[n]+'_'+str(n)+'_'+ track_name +'.mp3'
        #cmd = "curl -O %s %s" % (a_output, a_link)
        r = requests.get(a_link)
        with open(a_output,'wb') as f: 
            f.write(r.content)
        print(a_link)
        print(a_output)
        #os.system(cmd)
except:
    print("yo")
# Out:
# https://p.scdn.co/mp3-preview/e20c1aaa3a9cd0654d3315b31cf9d7079f244d63?cid=57daa17ab8e544dcab420c4b154c56d9
# disco_0_Best_of_My_Love.mp3
# https://p.scdn.co/mp3-preview/348cfde96da687058c927aaf84b5bfedd065b110?cid=57daa17ab8e544dcab420c4b154c56d9
# disco_1_Get_Down_Tonight___Edit.mp3
# https://p.scdn.co/mp3-preview/1f826380a449ec9a8bae45967d908fffd7ff5222?cid=57daa17ab8e544dcab420c4b154c56d9
# disco_2_Can_t_Hold_Us___feat._Ray_Dalton.mp3
# yo

# %%
track_name_list[0]
genre_list[0]
# Out:
# 'disco'
