# %%
from spotipy.oauth2 import SpotifyClientCredentials
import matplotlib.pyplot as plt
import pandas as pd
import requests
import spotipy 
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import requests
import json
import re
import requests
import urllib.request
import re
from bs4 import BeautifulSoup
import os

# %%
from config import cid
from config import secret
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
dataframe_1=pd.read_csv("disco1.csv")
dataframe_1.head()
# Out:
#                  Track_ID                               Track_Name  \
# 0  0x1LCpY9Rgeq97VPajm81B                           Cyclone - Main
# 1  1v5cgIyffYtfEx0swttdoE                          Bring Da Ruckus
# 2  1uL78kFWxhz3umTMWJu8n5                              Sauce It Up
# 3  7xq3uN2toVZ8IbNzfTucyJ                                Calm Down
# 4  3eze1OsZ1rqeXkKStNfTmi  Juke Jam (feat. Justin Bieber & Towkio)
#
#                                         Track_Artist  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
# 1  [{'external_urls': {'spotify': 'https://open.s...
# 2  [{'external_urls': {'spotify': 'https://open.s...
# 3  [{'external_urls': {'spotify': 'https://open.s...
# 4  [{'external_urls': {'spotify': 'https://open.s...
#
#                                          Preview_URL
# 0  https://p.scdn.co/mp3-preview/ff0fa0fc3861b50d...
# 1  https://p.scdn.co/mp3-preview/e5ac5724007e3954...
# 2  https://p.scdn.co/mp3-preview/0347d93ed9de9904...
# 3  https://p.scdn.co/mp3-preview/e913f550f3b8ff15...
# 4  https://p.scdn.co/mp3-preview/c60b5e2b4e87e462...

# %%
dataframe_2=pd.read_csv("disco2.csv")
dataframe_2.head()
# Out:
#                  Track_ID             Track_Name  \
# 0  0Altlm3kLPob56k2qqR4i2    Money and the Power
# 1  4GXl8l1MfZPf2GvpyRPJBf      pick up the phone
# 2  5n5uyFpfopa4mNdSN0gTaH                  Wing$
# 3  0msneWUDfYKAGrifwEDhtl  San Francisco Knights
# 4  0ySCYRXVugL9xDBecGc0jr  It Ain't Hard to Tell
#
#                                         Track_Artist  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
# 1  [{'external_urls': {'spotify': 'https://open.s...
# 2  [{'external_urls': {'spotify': 'https://open.s...
# 3  [{'external_urls': {'spotify': 'https://open.s...
# 4  [{'external_urls': {'spotify': 'https://open.s...
#
#                                          Preview_URL
# 0  https://p.scdn.co/mp3-preview/fa3cfc2b25fb07b5...
# 1  https://p.scdn.co/mp3-preview/20b453e9c63f9b07...
# 2  https://p.scdn.co/mp3-preview/c395f9bd916e0eed...
# 3  https://p.scdn.co/mp3-preview/530253b09e94ed8f...
# 4  https://p.scdn.co/mp3-preview/ca9bf2cdf6d177d3...

# %%
dataframe_3 = pd.read_csv("disco3.csv")
dataframe_3.head()
# Out:
#                  Track_ID                    Track_Name  \
# 0  0lpRp9KzzMbC0w1uiL7H7f                   Fruit Punch
# 1  7xq3uN2toVZ8IbNzfTucyJ                     Calm Down
# 2  1WIZiOuNO3woKfdlSK2gNn                  Transportin'
# 3  5t8djD6oZcfAyqF4cTQfFb  Real Rich (feat. Gucci Mane)
# 4  0Fpen1PTuEnCmOJtUU9Iud                     New Patek
#
#                                         Track_Artist  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
# 1  [{'external_urls': {'spotify': 'https://open.s...
# 2  [{'external_urls': {'spotify': 'https://open.s...
# 3  [{'external_urls': {'spotify': 'https://open.s...
# 4  [{'external_urls': {'spotify': 'https://open.s...
#
#                                          Preview_URL
# 0  https://p.scdn.co/mp3-preview/db9e29e10bb75419...
# 1  https://p.scdn.co/mp3-preview/e913f550f3b8ff15...
# 2  https://p.scdn.co/mp3-preview/dc943e9eeed11c3e...
# 3  https://p.scdn.co/mp3-preview/68d74fd49a1a56bf...
# 4  https://p.scdn.co/mp3-preview/7230641a984e8b59...

# %%
dataframe_4 = pd.read_csv("disco4.csv")
dataframe_4.head()
# Out:
#                  Track_ID                             Track_Name  \
# 0  6YbhspuOar1D9WSSnfe7ds  Young, Wild & Free (feat. Bruno Mars)
# 1  2eAZfqOm4EnOF9VvN50Tyc    The Way Life Goes (feat. Oh Wonder)
# 2  4Km5HrUvYTaSUfiSGPJeQR    Bad and Boujee (feat. Lil Uzi Vert)
# 3  6aSpOtfzxFZ7hy0Bom7c1k                          I Wanna Smoke
# 4  1RagpNpkD3KcjXMLGMe99V                Fr Fr (feat. Lil Skies)
#
#                                         Track_Artist  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
# 1  [{'external_urls': {'spotify': 'https://open.s...
# 2  [{'external_urls': {'spotify': 'https://open.s...
# 3  [{'external_urls': {'spotify': 'https://open.s...
# 4  [{'external_urls': {'spotify': 'https://open.s...
#
#                                          Preview_URL
# 0  https://p.scdn.co/mp3-preview/8c67ffec7842ba4d...
# 1  https://p.scdn.co/mp3-preview/4d282cabd448444f...
# 2  https://p.scdn.co/mp3-preview/7692f50253957345...
# 3  https://p.scdn.co/mp3-preview/b5f56647d443dc01...
# 4  https://p.scdn.co/mp3-preview/5761e4ab6a99b894...

# %%
dataframe_5 = pd.read_csv("disco5.csv")
dataframe_5.head()
# Out:
#                  Track_ID                                  Track_Name  \
# 0  5Gx2SIkIWdSzdxnvfO3TJy  Heartless (feat. Rick Ross & Bigga Rankin)
# 1  2cGJxXXIBrxMhk2fWUJTLs  Ooh Ahh (My Life Be Like) (feat. Toby Mac)
# 2  6bUNEbXT7HovLW6BgPCBsb                                       Roses
# 3  5LN1B9uVAVleCZ2euGarvi                                         MVP
# 4  5FX89IUKm9QJT9ymrmyK4k                                  Free Lunch
#
#                                         Track_Artist  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
# 1  [{'external_urls': {'spotify': 'https://open.s...
# 2  [{'external_urls': {'spotify': 'https://open.s...
# 3  [{'external_urls': {'spotify': 'https://open.s...
# 4  [{'external_urls': {'spotify': 'https://open.s...
#
#                                          Preview_URL
# 0  https://p.scdn.co/mp3-preview/928f7aeaa3e16a7d...
# 1  https://p.scdn.co/mp3-preview/2041709b6679c0ac...
# 2  https://p.scdn.co/mp3-preview/7885d31300d2c947...
# 3  https://p.scdn.co/mp3-preview/da5feaf26b51df90...
# 4  https://p.scdn.co/mp3-preview/da50e966d3cba78b...

# %%
dataframe_6 = pd.read_csv("disco6.csv")
dataframe_6.head()
# Out:
#                  Track_ID           Track_Name  \
# 0  7IhsLJMqdxoo7YAZjaSMru        Dead And Gone
# 1  1IAzD1muglOxOcPbUHs70R    Whatever You Like
# 2  49zD0wr2S3d0lZPib0K4e1  F*ck Up Some Commas
# 3  6GAemDMWAXa8wZOBkO1gar          Buggin' Out
# 4  4kxAgnWw4GKmqcuUiXn60o            Represent
#
#                                         Track_Artist  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
# 1  [{'external_urls': {'spotify': 'https://open.s...
# 2  [{'external_urls': {'spotify': 'https://open.s...
# 3  [{'external_urls': {'spotify': 'https://open.s...
# 4  [{'external_urls': {'spotify': 'https://open.s...
#
#                                          Preview_URL
# 0  https://p.scdn.co/mp3-preview/66fcdde9a21b8b63...
# 1  https://p.scdn.co/mp3-preview/c82678be83d118b5...
# 2  https://p.scdn.co/mp3-preview/374e7f17d3d4206d...
# 3  https://p.scdn.co/mp3-preview/71522856a0603736...
# 4  https://p.scdn.co/mp3-preview/f0619eab1b4d436e...

# %%
dataframe_7 = pd.read_csv("disco7.csv")
dataframe_7.head()
# Out:
#                  Track_ID                                         Track_Name  \
# 0  04Rz403IY7QUqgfrTWX6OU                                       Da Graveyard
# 1  7r6LNJT2LqpLpEyZQJPygt                         Patek Water (feat. Offset)
# 2  0shK5iZQppbHPQYiy60xs9                                         Rosa Parks
# 3  4bTP7W5HEJYG0jR6EMfNka  I Guess I'll Smoke (feat. Dizzy Wright & Layzi...
# 4  0lpRp9KzzMbC0w1uiL7H7f                                        Fruit Punch
#
#                                         Track_Artist  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
# 1  [{'external_urls': {'spotify': 'https://open.s...
# 2  [{'external_urls': {'spotify': 'https://open.s...
# 3  [{'external_urls': {'spotify': 'https://open.s...
# 4  [{'external_urls': {'spotify': 'https://open.s...
#
#                                          Preview_URL
# 0  https://p.scdn.co/mp3-preview/20933036c8216e6c...
# 1  https://p.scdn.co/mp3-preview/ab0d45ffc05e9043...
# 2  https://p.scdn.co/mp3-preview/e3dabbb4cb699225...
# 3  https://p.scdn.co/mp3-preview/940d626d07be5d25...
# 4  https://p.scdn.co/mp3-preview/db9e29e10bb75419...

# %%
pd.merge(left, right, how ='inner', on ='Sr.no') 

final_df = pd.concat([dataframe_1, dataframe_2, dataframe_3, dataframe_4, dataframe_5,dataframe_6,dataframe_7], ignore_index=True)
final_df
# Out:
#                    Track_ID                               Track_Name  \
# 0    0x1LCpY9Rgeq97VPajm81B                           Cyclone - Main
# 1    1v5cgIyffYtfEx0swttdoE                          Bring Da Ruckus
# 2    1uL78kFWxhz3umTMWJu8n5                              Sauce It Up
# 3    7xq3uN2toVZ8IbNzfTucyJ                                Calm Down
# 4    3eze1OsZ1rqeXkKStNfTmi  Juke Jam (feat. Justin Bieber & Towkio)
# ..                      ...                                      ...
# 307  6JI5wNWYdBw68GZjOMmgK5                                Put It On
# 308  1B5BfvGVQ5fPtDN2K8tUdy         Memory Lane (Sittin' in da Park)
# 309  4Km5HrUvYTaSUfiSGPJeQR      Bad and Boujee (feat. Lil Uzi Vert)
# 310  43ZyHQITOjhciSUUNPVRHc                               Gucci Gang
# 311  1uL78kFWxhz3umTMWJu8n5                              Sauce It Up
#
#                                           Track_Artist  \
# 0    [{'external_urls': {'spotify': 'https://open.s...
# 1    [{'external_urls': {'spotify': 'https://open.s...
# 2    [{'external_urls': {'spotify': 'https://open.s...
# 3    [{'external_urls': {'spotify': 'https://open.s...
# 4    [{'external_urls': {'spotify': 'https://open.s...
# ..                                                 ...
# 307  [{'external_urls': {'spotify': 'https://open.s...
# 308  [{'external_urls': {'spotify': 'https://open.s...
# 309  [{'external_urls': {'spotify': 'https://open.s...
# 310  [{'external_urls': {'spotify': 'https://open.s...
# 311  [{'external_urls': {'spotify': 'https://open.s...
#
#                                            Preview_URL
# 0    https://p.scdn.co/mp3-preview/ff0fa0fc3861b50d...
# 1    https://p.scdn.co/mp3-preview/e5ac5724007e3954...
# 2    https://p.scdn.co/mp3-preview/0347d93ed9de9904...
# 3    https://p.scdn.co/mp3-preview/e913f550f3b8ff15...
# 4    https://p.scdn.co/mp3-preview/c60b5e2b4e87e462...
# ..                                                 ...
# 307  https://p.scdn.co/mp3-preview/0b97d437197b7a08...
# 308  https://p.scdn.co/mp3-preview/5f1577c55f28ef86...
# 309  https://p.scdn.co/mp3-preview/7692f50253957345...
# 310  https://p.scdn.co/mp3-preview/c1136bf2d8c9c35a...
# 311  https://p.scdn.co/mp3-preview/0347d93ed9de9904...
#
# [312 rows x 4 columns]

# %%
final_h_metal_merge_df = final_df.dropna(how = 'any')
final_h_metal_merge_df = final_h_metal_merge_df.drop_duplicates
final_h_metal_merge_df.to_csv("h_metal.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-00bc1eca622f> in <module>
#       1 final_h_metal_merge_df = final_df.dropna(how = 'any')
#       2 final_h_metal_merge_df = final_h_metal_merge_df.drop_duplicates
# ----> 3 final_h_metal_merge_df.to_csv("h_metal.csv")
#
# AttributeError: 'function' object has no attribute 'to_csv'

# %%
h_metal = pd.read_csv("h_metal.csv")
h_metal

# %%
preview_list = h_metal['Preview_link'].tolist()
print(preview_list)
genre_list = h_metal['Genre'].tolist()
print(genre_list)
track_name_list = h_metal['Track Name'].tolist()
print(track_name_list)

# %%
os.chdir('/Users/heesungshim/Desktop/2_Homework_BTC/final_group_project/heavy_metal/heavy_metal_mp3')
for n, a_link in enumerate(preview_list):
    track_name = track_name_list[n].replace(' ', '_')
    track_name = track_name.replace('""', "''")
    track_name = track_name.replace("'", '_')
    track_name = track_name.replace('(', '_')
    track_name = track_name.replace(')', '_')
    track_name = track_name.replace('&', '_')
    track_name = track_name.replace('-', '_')
    track_name = track_name.replace('/', '_')
    a_output = genre_list[n]+'_'+str(n)+'_'+ track_name +'.mp3'
    cmd = "wget -O %s %s" % (a_output, a_link)
    print(cmd)
    os.system(cmd)

# %%
track_name_list[0]
genre_list[0]
