# %%
from spotipy.oauth2 import SpotifyClientCredentials
import matplotlib.pyplot as plt
import pandas as pd
import requests
import spotipy 
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import requests
import json
import re
import requests
import urllib.request
import re
from bs4 import BeautifulSoup
import os

# %%
from config import cid
from config import secret
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
dataframe_1=pd.read_csv("disco1.csv")
dataframe_1.head()
# Out:
#    Unnamed: 0                Track_ID  \
# 0           0  2Cd9iWfcOpGDHLz6tVA3G4
# 1           3  0s45sL9DLOcro6VbmagQKl
# 2           4  3XIEWK1V9n25PS9Vb6axj5
# 3           5  4rwpZEcnalkuhPyGkEdhu0
# 4           6  1wRHNlEjTmpaXv99BFAGnV
#
#                                           Track_Name  \
# 0  Waka Waka (This Time for Africa) [The Official...
# 1                                      Rock the Boat
# 2                                   Born to Be Alive
# 3                    Scary Monsters and Nice Sprites
# 4                    Got To Be Real - Single Version
#
#                                         Track_Artist  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
# 1  [{'external_urls': {'spotify': 'https://open.s...
# 2  [{'external_urls': {'spotify': 'https://open.s...
# 3  [{'external_urls': {'spotify': 'https://open.s...
# 4  [{'external_urls': {'spotify': 'https://open.s...
#
#                                          Preview_URL
# 0  https://p.scdn.co/mp3-preview/f01830f7be6c8b65...
# 1  https://p.scdn.co/mp3-preview/d9acc6522961aa4f...
# 2  https://p.scdn.co/mp3-preview/5ec427ac93acfe64...
# 3  https://p.scdn.co/mp3-preview/fd1cb014b2eb27e1...
# 4  https://p.scdn.co/mp3-preview/5316488d9a73562b...

# %%
dataframe_2=pd.read_csv("disco2.csv")
dataframe_2.head()
# Out:
#    Unnamed: 0                Track_ID  \
# 0           0  5J2UfqBylH8jDQZJnxby81
# 1           2  3MFa9idQuY4iJLWsZl3tIQ
# 2           3  4d2hD63oUGU3s7L66JD0BE
# 3           4  38iU2jg98IZZEIJPrP7aWD
# 4           5  46eu3SBuFCXWsPT39Yg3tJ
#
#                                         Track_Name  \
# 0                            Sean den förste Banan
# 1                            Young Hearts Run Free
# 2                                      Dance Again
# 3                              Till the World Ends
# 4  Don't Stop 'Til You Get Enough - Single Version
#
#                                         Track_Artist  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
# 1  [{'external_urls': {'spotify': 'https://open.s...
# 2  [{'external_urls': {'spotify': 'https://open.s...
# 3  [{'external_urls': {'spotify': 'https://open.s...
# 4  [{'external_urls': {'spotify': 'https://open.s...
#
#                                          Preview_URL
# 0  https://p.scdn.co/mp3-preview/efb64c7d08ad4d0b...
# 1  https://p.scdn.co/mp3-preview/b0b96bb7e0e4f151...
# 2  https://p.scdn.co/mp3-preview/2d288b4a7117b800...
# 3  https://p.scdn.co/mp3-preview/fd017ae5c0a60cff...
# 4  https://p.scdn.co/mp3-preview/bcbf2c53e033e4df...

# %%
dataframe_3 = pd.read_csv("disco3.csv")
dataframe_3.head()
# Out:
#    Unnamed: 0                Track_ID                              Track_Name  \
# 0           0  2M55R2A9IAhLdsCGFj8r8k                         I'm Every Woman
# 1           1  62zFEHfAYl5kdHYOivj4BC  International Love (feat. Chris Brown)
# 2           3  6UjlpJhUqOQqv0hrb38IDI                         Best of My Love
# 3           4  0D2VYiRlBv43asKUgieZaM                      Jubel - Radio Edit
# 4           8  20zOIoex7YchUh87d8tlvg                           Boogie Nights
#
#                                         Track_Artist  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
# 1  [{'external_urls': {'spotify': 'https://open.s...
# 2  [{'external_urls': {'spotify': 'https://open.s...
# 3  [{'external_urls': {'spotify': 'https://open.s...
# 4  [{'external_urls': {'spotify': 'https://open.s...
#
#                                          Preview_URL
# 0  https://p.scdn.co/mp3-preview/4e7ba67fbaac1b59...
# 1  https://p.scdn.co/mp3-preview/23235746b5a67425...
# 2  https://p.scdn.co/mp3-preview/e20c1aaa3a9cd065...
# 3  https://p.scdn.co/mp3-preview/609d21d24ab7a92e...
# 4  https://p.scdn.co/mp3-preview/2675fa781631556b...

# %%
dataframe_4 = pd.read_csv("disco4.csv")
dataframe_4.head()
# Out:
#    Unnamed: 0                Track_ID               Track_Name  \
# 0           0  7IJdhXX43QDoTNQeBRxZHu             Ladies Night
# 1           3  3WMbD1OyfKuwWDWMNbPQ4g               Daddy Cool
# 2           4  38iU2jg98IZZEIJPrP7aWD      Till the World Ends
# 3           6  6UjlpJhUqOQqv0hrb38IDI          Best of My Love
# 4          10  0fYbhMj96zG9fpUK10e8kB  Don't Leave Me This Way
#
#                                         Track_Artist  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
# 1  [{'external_urls': {'spotify': 'https://open.s...
# 2  [{'external_urls': {'spotify': 'https://open.s...
# 3  [{'external_urls': {'spotify': 'https://open.s...
# 4  [{'external_urls': {'spotify': 'https://open.s...
#
#                                          Preview_URL
# 0  https://p.scdn.co/mp3-preview/b6b8924a097ffcad...
# 1  https://p.scdn.co/mp3-preview/191db1a9fda30574...
# 2  https://p.scdn.co/mp3-preview/fd017ae5c0a60cff...
# 3  https://p.scdn.co/mp3-preview/e20c1aaa3a9cd065...
# 4  https://p.scdn.co/mp3-preview/f53364e19d81973a...

# %%
dataframe_5 = pd.read_csv("disco5.csv")
dataframe_5.head()
# Out:
#    Unnamed: 0                Track_ID                       Track_Name  \
# 0           0  3XIEWK1V9n25PS9Vb6axj5                 Born to Be Alive
# 1           1  4rVxIA2PfuPaFsVH5AOqIm               My Forbidden Lover
# 2           4  3bFK0tj9d6IWdAUSX3oylo  Lady Marmalade - Single Version
# 3           7  3JO3ywp8UufIiKkszm7DkE                    Flytta på dej
# 4           8  2UVLuddklEVak5PXgC7baA           Groove Is in the Heart
#
#                                         Track_Artist  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
# 1  [{'external_urls': {'spotify': 'https://open.s...
# 2  [{'external_urls': {'spotify': 'https://open.s...
# 3  [{'external_urls': {'spotify': 'https://open.s...
# 4  [{'external_urls': {'spotify': 'https://open.s...
#
#                                          Preview_URL
# 0  https://p.scdn.co/mp3-preview/5ec427ac93acfe64...
# 1  https://p.scdn.co/mp3-preview/c142f667b2223b74...
# 2  https://p.scdn.co/mp3-preview/0678f39429aeb696...
# 3  https://p.scdn.co/mp3-preview/75b9470bab694930...
# 4  https://p.scdn.co/mp3-preview/9f04c5adba941577...

# %%
dataframe_6 = pd.read_csv("disco6.csv")
dataframe_6.head()
# Out:
#    Unnamed: 0                Track_ID                      Track_Name  \
# 0           1  2gNAGt7gUiMkagkhIiDLPm                     Dansa Pausa
# 1           6  3s4U7OHV7gnj42VV72eSZ6   Rather Be (feat. Jess Glynne)
# 2           9  5MCpdJawYOuGRVui6zP8qx  Rock Your Baby (Album Version)
# 3          10  1CmUZGtH29Kx36C1Hleqlz        Thrift Shop (feat. Wanz)
# 4          11  2DX0WG5OGLQLaXb41Cq1IA     I Will Survive - Remastered
#
#                                         Track_Artist  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
# 1  [{'external_urls': {'spotify': 'https://open.s...
# 2  [{'external_urls': {'spotify': 'https://open.s...
# 3  [{'external_urls': {'spotify': 'https://open.s...
# 4  [{'external_urls': {'spotify': 'https://open.s...
#
#                                          Preview_URL
# 0  https://p.scdn.co/mp3-preview/7872b49150e61748...
# 1  https://p.scdn.co/mp3-preview/a9d9d2d68603e22d...
# 2  https://p.scdn.co/mp3-preview/af43aaf2cef68526...
# 3  https://p.scdn.co/mp3-preview/26cdc03872031160...
# 4  https://p.scdn.co/mp3-preview/136f43b54553a7ea...

# %%
dataframe_7 = pd.read_csv("disco7.csv")
dataframe_7.head()
# Out:
#    Unnamed: 0                Track_ID  \
# 0           3  2Foc5Q5nqNiosCNqttzHof
# 1           4  0TDLuuLlV54CkRRUOahJb4
# 2          10  3GGcwG519BTMdvMeFy7meT
# 3          17  7qfwcqfGOkQYtzjF4UzJHM
# 4          19  0Qqrehp0IC6ppqIUz6mPCe
#
#                                           Track_Name  \
# 0  Get Lucky (feat. Pharrell Williams & Nile Rodg...
# 1                               Titanium (feat. Sia)
# 2                                     Lady Marmalade
# 3      Shot Me Down (feat. Skylar Grey) - Radio Edit
# 4                                     No Sigue Modas
#
#                                         Track_Artist  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
# 1  [{'external_urls': {'spotify': 'https://open.s...
# 2  [{'external_urls': {'spotify': 'https://open.s...
# 3  [{'external_urls': {'spotify': 'https://open.s...
# 4  [{'external_urls': {'spotify': 'https://open.s...
#
#                                          Preview_URL
# 0  https://p.scdn.co/mp3-preview/92d40a2ae211cceb...
# 1  https://p.scdn.co/mp3-preview/06392eaab5975806...
# 2  https://p.scdn.co/mp3-preview/da137cbab59ef54b...
# 3  https://p.scdn.co/mp3-preview/217f039111aedd04...
# 4  https://p.scdn.co/mp3-preview/fe8712dfc9264371...

# %%
#dataframe_8 = pd.read_csv("h_metal_track_dataframe_8.csv")
#dataframe_8.head()

# %%
final_df = pd.concat([dataframe_1, dataframe_2, dataframe_3, dataframe_4, dataframe_5,dataframe_6,dataframe_7], ignore_index=True)
final_df
# Out:
#      Unnamed: 0                Track_ID  \
# 0             0  2Cd9iWfcOpGDHLz6tVA3G4
# 1             3  0s45sL9DLOcro6VbmagQKl
# 2             4  3XIEWK1V9n25PS9Vb6axj5
# 3             5  4rwpZEcnalkuhPyGkEdhu0
# 4             6  1wRHNlEjTmpaXv99BFAGnV
# ..          ...                     ...
# 295          87  6UjlpJhUqOQqv0hrb38IDI
# 296          88  1Apsc59v5KojwhFEVmYoe4
# 297          90  0DDgwlJDTQ6U3LPzUyvLu5
# 298          96  2yFh7Oz9g0bpHp3iis2Iu2
# 299          99  6KlnQC66NiJTdO88aL62SF
#
#                                             Track_Name  \
# 0    Waka Waka (This Time for Africa) [The Official...
# 1                                        Rock the Boat
# 2                                     Born to Be Alive
# 3                      Scary Monsters and Nice Sprites
# 4                      Got To Be Real - Single Version
# ..                                                 ...
# 295                                    Best of My Love
# 296                                 Pick Up The Pieces
# 297                 Never Can Say Goodbye - Remastered
# 298                        Talk Dirty (feat. 2 Chainz)
# 299                                              Shame
#
#                                           Track_Artist  \
# 0    [{'external_urls': {'spotify': 'https://open.s...
# 1    [{'external_urls': {'spotify': 'https://open.s...
# 2    [{'external_urls': {'spotify': 'https://open.s...
# 3    [{'external_urls': {'spotify': 'https://open.s...
# 4    [{'external_urls': {'spotify': 'https://open.s...
# ..                                                 ...
# 295  [{'external_urls': {'spotify': 'https://open.s...
# 296  [{'external_urls': {'spotify': 'https://open.s...
# 297  [{'external_urls': {'spotify': 'https://open.s...
# 298  [{'external_urls': {'spotify': 'https://open.s...
# 299  [{'external_urls': {'spotify': 'https://open.s...
#
#                                            Preview_URL
# 0    https://p.scdn.co/mp3-preview/f01830f7be6c8b65...
# 1    https://p.scdn.co/mp3-preview/d9acc6522961aa4f...
# 2    https://p.scdn.co/mp3-preview/5ec427ac93acfe64...
# 3    https://p.scdn.co/mp3-preview/fd1cb014b2eb27e1...
# 4    https://p.scdn.co/mp3-preview/5316488d9a73562b...
# ..                                                 ...
# 295  https://p.scdn.co/mp3-preview/e20c1aaa3a9cd065...
# 296  https://p.scdn.co/mp3-preview/fa85990160ae1f34...
# 297  https://p.scdn.co/mp3-preview/9b9305d37539d1b1...
# 298  https://p.scdn.co/mp3-preview/222364acc5401773...
# 299  https://p.scdn.co/mp3-preview/8b07120f2f9c9156...
#
# [300 rows x 5 columns]

# %%
final_h_metal_merge_df = final_df.dropna(how = 'any')
final_h_metal_merge_df = final_h_metal_merge_df.drop_duplicates(subset=['Track ID'],keep='last')
final_h_metal_merge_df.reset_index()
final_h_metal_merge_df.drop(['Unnamed: 0'], axis=1)
final_h_metal_merge_df.to_csv("h_metal.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-0d23d2639ef9> in <module>
#       2 final_h_metal_merge_df = final_h_metal_merge_df.drop_duplicates#(subset=['Track ID'],keep='last')
#       3 #final_h_metal_merge_df.reset_index()
# ----> 4 final_h_metal_merge_df.drop(['Unnamed: 0'], axis=1)
#       5 final_h_metal_merge_df.to_csv("h_metal.csv")
#
# AttributeError: 'function' object has no attribute 'drop'

# %%
h_metal = pd.read_csv("h_metal.csv")
h_metal

# %%
preview_list = h_metal['Preview_link'].tolist()
print(preview_list)
genre_list = h_metal['Genre'].tolist()
print(genre_list)
track_name_list = h_metal['Track Name'].tolist()
print(track_name_list)

# %%
os.chdir('/Users/heesungshim/Desktop/2_Homework_BTC/final_group_project/heavy_metal/heavy_metal_mp3')
for n, a_link in enumerate(preview_list):
    track_name = track_name_list[n].replace(' ', '_')
    track_name = track_name.replace('""', "''")
    track_name = track_name.replace("'", '_')
    track_name = track_name.replace('(', '_')
    track_name = track_name.replace(')', '_')
    track_name = track_name.replace('&', '_')
    track_name = track_name.replace('-', '_')
    track_name = track_name.replace('/', '_')
    a_output = genre_list[n]+'_'+str(n)+'_'+ track_name +'.mp3'
    cmd = "wget -O %s %s" % (a_output, a_link)
    print(cmd)
    os.system(cmd)

# %%
track_name_list[0]
genre_list[0]
