# %%
from spotipy.oauth2 import SpotifyClientCredentials
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import requests
import spotipy 
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import requests
import json

# %%
from config import cid
from config import secret
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
randoms = sp.recommendations(seed_genres=['disco'], limit=100)

# %%
tracks_preview = []
tracks_id = []
tracks_name = []
tracks_artist = []
tracks_album = []

for album_ind in range(0, 100):
    tracks_preview.append(randoms['tracks'][album_ind]['preview_url'])
    tracks_id.append(randoms['tracks'][album_ind]['id'])
    tracks_name.append(randoms['tracks'][album_ind]['name'])
    tracks_artist.append(randoms['tracks'][album_ind]['artists'])
    
print(tracks_artist)
print(tracks_album)
# Out:
# [[{'external_urls': {'spotify': 'https://open.spotify.com/artist/0bShb58TO0fM5jOjXhB1WT'}, 'href': 'https://api.spotify.com/v1/artists/0bShb58TO0fM5jOjXhB1WT', 'id': '0bShb58TO0fM5jOjXhB1WT', 'name': 'Van McCoy', 'type': 'artist', 'uri': 'spotify:artist:0bShb58TO0fM5jOjXhB1WT'}], [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3mQBpAOMWYqAZyxtyeo4Lo'}, 'href': 'https://api.spotify.com/v1/artists/3mQBpAOMWYqAZyxtyeo4Lo', 'id': '3mQBpAOMWYqAZyxtyeo4Lo', 'name': 'KC & The Sunshine Band', 'type': 'artist', 'uri': 'spotify:artist:3mQBpAOMWYqAZyxtyeo4Lo'}], [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6MF9fzBmfXghAz953czmBC'}, 'href': 'https://api.spotify.com/v1/artists/6MF9fzBmfXghAz953czmBC', 'id': '6MF9fzBmfXghAz953czmBC', 'name': 'Taio Cruz', 'type': 'artist', 'uri': 'spotify:artist:6MF9fzBmfXghAz953czmBC'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/0jnsk9HBra6NMjO2oANoPY'}, 'href': 'https://api.spotify.com/v1/artists/0jnsk9HBra6NMjO2oANoPY', 'id': '0jnsk9HBra6NMjO2oANoPY', 'name': 'Flo Rida', 'type': 'artist', 'uri': 'spotify:artist:0jnsk9HBra6NMjO2oANoPY'}], [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5bv5RplEOwdCvhq0EILh9E'}, 'href': 'https://api.spotify.com/v1/artists/5bv5RplEOwdCvhq0EILh9E', 'id': '5bv5RplEOwdCvhq0EILh9E', 'name': 'Lucenzo', 'type': 'artist', 'uri': 'spotify:artist:5bv5RplEOwdCvhq0EILh9E'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/33ScadVnbm2X8kkUqOkC6Z'}, 'href': 'https://api.spotify.com/v1/artists/33ScadVnbm2X8kkUqOkC6Z', 'id': '33ScadVnbm2X8kkUqOkC6Z', 'name': 'Don Omar', 'type': 'artist', 'uri': 'spotify:artist:33ScadVnbm2X8kkUqOkC6Z'}], [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7CajNmpbOovFoOoasH2HaY'}, 'href': 'https://api.spotify.com/v1/artists/7CajNmpbOovFoOoasH2HaY', 'id': '7CajNmpbOovFoOoasH2HaY', 'name': 'Calvin Harris', 'type': 'artist', 'uri': 'spotify:artist:7CajNmpbOovFoOoasH2HaY'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/0IROOdQ2fQUcoaEPqt1Isg'}, 'href': 'https://api.spotify.com/v1/artists/0IROOdQ2fQUcoaEPqt1Isg', 'id': '0IROOdQ2fQUcoaEPqt1Isg', 'name': 'Florence Welch', 'type': 'artist', 'uri': 'spotify:artist:0IROOdQ2fQUcoaEPqt1Isg'}], [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6BkcAbUkfIBM4XudxieMq8'}, 'href': 'https://api.spotify.com/v1/artists/6BkcAbUkfIBM4XudxieMq8', 'id': '6BkcAbUkfIBM4XudxieMq8', 'name': 'Dr. Alban', 'type': 'artist', 'uri': 'spotify:artist:6BkcAbUkfIBM4XudxieMq8'}], [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3r17AfJCCUqC9Lf0OAc73G'}, 'href': 'https://api.spotify.com/v1/artists/3r17AfJCCUqC9Lf0OAc73G', 'id': '3r17AfJCCUqC9Lf0OAc73G', 'name': 'Fergie', 'type': 'artist', 'uri': 'spotify:artist:3r17AfJCCUqC9Lf0OAc73G'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/3ZotbHeyVQKxQCPDJuQ4SU'}, 'href': 'https://api.spotify.com/v1/artists/3ZotbHeyVQKxQCPDJuQ4SU', 'id': '3ZotbHeyVQKxQCPDJuQ4SU', 'name': 'Q-Tip', 'type': 'artist', 'uri': 'spotify:artist:3ZotbHeyVQKxQCPDJuQ4SU'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/53sIBaVjXQhfH89Vu6nEGh'}, 'href': 'https://api.spotify.com/v1/artists/53sIBaVjXQhfH89Vu6nEGh', 'id': '53sIBaVjXQhfH89Vu6nEGh', 'name': 'GoonRock', 'type': 'artist', 'uri': 'spotify:artist:53sIBaVjXQhfH89Vu6nEGh'}], [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qI4LTzMRpTxRzMZPvv2C6'}, 'href': 'https://api.spotify.com/v1/artists/6qI4LTzMRpTxRzMZPvv2C6', 'id': '6qI4LTzMRpTxRzMZPvv2C6', 'name': 'Peaches & Herb', 'type': 'artist', 'uri': 'spotify:artist:6qI4LTzMRpTxRzMZPvv2C6'}], [{'external_urls': {'spotify': 'https://open.spotify.com/artist/64CuUOOirKmdAYLQSfaOyr'}, 'href': 'https://api.spotify.com/v1/artists/64CuUOOirKmdAYLQSfaOyr', 'id': '64CuUOOirKmdAYLQSfaOyr', 'name': 'The Emotions', 'type': 'artist', 'uri': 'spotify:artist:64CuUOOirKmdAYLQSfaOyr'}], [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HvcqyR ...
# []

# %%
tracks_data = {'Track_ID':tracks_id, 
               'Track_Name':tracks_name, 
               'Track_Artist':tracks_artist, 
               'Preview_URL':tracks_preview}

tracks_df = pd.DataFrame(tracks_data)
#racks_df = tracks_df[tracks_df["Preview_URL"] != "Null"]
#tracks_df = tracks_df[tracks_df.Preview_URL != None]
tracks_df = tracks_df.replace(to_replace='None', value=np.nan).dropna()
#tracks_data.dropna()
tracks_df
# Out:
#                   Track_ID                                         Track_Name  \
# 3   1kAZhbcsXqfUjnVeqPywn2                      Danza Kuduro (feat. Don Omar)
# 4   24LS4lQShWyixJ0ZrJXfJ5               Sweet Nothing (feat. Florence Welch)
# 5   6HdM7gzXVgcpepv276raog                                       It's My Life
# 8   6UjlpJhUqOQqv0hrb38IDI                                    Best of My Love
# 9   7gssYOCe03w6yC1JMjXiCN                                     Instant Replay
# 11  6VRhkROS2SZHGlp0pxndbJ                            Bangarang (feat. Sirah)
# 15  3rhnT5RoN7bvPUpMHt1aM9                                         La La Love
# 18  5TgD3Wh5ZUZnUU4tmVvJbx                                   It's Raining Men
# 19  2DX0WG5OGLQLaXb41Cq1IA                        I Will Survive - Remastered
# 3   [{'external_urls': {'spotify': 'https://open.s...
# 4   [{'external_urls': {'spotify': 'https://open.s...
# 5   [{'external_urls': {'spotify': 'https://open.s...
# 8   [{'external_urls': {'spotify': 'https://open.s...
# 9   [{'external_urls': {'spotify': 'https://open.s...
# 11  [{'external_urls': {'spotify': 'https://open.s...
# 15  [{'external_urls': {'spotify': 'https://open.s...
# 18  [{'external_urls': {'spotify': 'https://open.s...
# 19  [{'external_urls': {'spotify': 'https://open.s...
# 21  [{'external_urls': {'spotify': 'https://open.s...
# 22  [{'external_urls': {'spotify': 'https://open.s...
# 23  [{'external_urls': {'spotify': 'https://open.s...
# 26  [{'external_urls': {'spotify': 'https://open.s...
# 27  [{'external_urls': {'spotify': 'https://open.s...
# 28  [{'external_urls': {'spotify': 'https://open.s...
# 31  [{'external_urls': {'spotify': 'https://open.s...
# 33  [{'external_urls': {'spotify': 'https://open.s...
# 34  [{'external_urls': {'spotify': 'https://open.s...
# 41  [{'external_urls': {'spotify': 'https://open.s...
# 42  [{'external_urls': {'spotify': 'https://open.s...
# 44  [{'external_urls': {'spotify': 'https://open.s...
# 46  [{'external_urls': {'spotify': 'https://open.s...
# 47  [{'external_urls': {'spotify': 'https://open.s...
# 52  [{'external_urls': {'spotify': 'https://open.s...
# 53  [{'external_urls': {'spotify': 'https://open.s...
# 54  [{'external_urls': {'spotify': 'https://open.s...
# 59  [{'external_urls': {'spotify': 'https://open.s...
# 60  [{'external_urls': {'spotify': 'https://open.s...
# 61  [{'external_urls': {'spotify': 'https://open.s...
# 63  [{'external_urls': {'spotify': 'https://open.s...
# 64  [{'external_urls': {'spotify': 'https://open.s...
# 65  [{'external_urls': {'spotify': 'https://open.s...
# 69  [{'external_urls': {'spotify': 'https://open.s...
# 70  [{'external_urls': {'spotify': 'https://open.s...
# 73  [{'external_urls': {'spotify': 'https://open.s...
# 78  [{'external_urls': {'spotify': 'https://open.s...
# 79  [{'external_urls': {'spotify': 'https://open.s...
# 82  [{'external_urls': {'spotify': 'https://open.s...
# 83  [{'external_urls': {'spotify': 'https://open.s...
# 85  [{'external_urls': {'spotify': 'https://open.s...
# 87  [{'external_urls': {'spotify': 'https://open.s...
# 88  [{'external_urls': {'spotify': 'https://open.s...
# 90  [{'external_urls': {'spotify': 'https://open.s...
# 96  [{'external_urls': {'spotify': 'https://open.s...
# 97  [{'external_urls': {'spotify': 'https://open.s...
# 98  [{'external_urls': {'spotify': 'https://open.s...
# 99  [{'external_urls': {'spotify': 'https://open.s...
#
#                                           Preview_URL
# 3   https://p.scdn.co/mp3-preview/de9358c4194d430a...
# 4   https://p.scdn.co/mp3-preview/34ef2c315f140d22...
# 5   https://p.scdn.co/mp3-preview/161554d92cc88e78...
# 8   https://p.scdn.co/mp3-preview/e20c1aaa3a9cd065...
# 9   https://p.scdn.co/mp3-preview/9f146a1f91e2ee47...
# 11  https://p.scdn.co/mp3-preview/569d7afebba42141...
# 15  https://p.scdn.co/mp3-preview/f133cb3b56830b3e...
# 18  https://p.scdn.co/mp3-preview/14f845ed905fdee6...
# 19  https://p.scdn.co/mp3-preview/136f43b54553a7ea...
# 21  https://p.scdn.co/mp3-preview/1a0f32d036929246...
# 22  https://p.scdn.co/mp3-preview/cab09cebe3d33abf...
# 23  https://p.scdn.co/mp3-preview/5ec427ac93acfe64...
# 26  https://p.scdn.co/mp3-preview/b932b066df9e4929...
# 27  https://p.scdn.co/mp3-preview/f504e6b8e0377713...
# 28  https://p.scdn.co/mp3-preview/3ce8820ec020ffbe...
# 31  https://p.scdn.co/mp3-preview/5316488d9a73562b...
# 33  https://p.scdn.co/mp3-preview/26f5886af9af728d...
# 34  https://p.scdn.co/mp3-preview/dea782268ddbd6e5...
# 41  https://p.scdn.co/mp3-preview/c09599c6378ab14c...
# 42  https://p.scdn.co/mp3-preview/fd017ae5c0a60cff...
# 44  https://p.scdn.co/mp3-preview/c23dd5c75469c4d4...
# 46  https://p.scdn.co/mp3-preview/659374a67e87fcdc...
# 47  https://p.scdn.co/mp3-preview/a8bca3766ae98ca2...
# 52  https://p.scdn.co/mp3-preview/2780356e9a11fab4...
# 53  https://p.scdn.co/mp3-preview/02a8a9e9982c7eb5...
# 54  https://p.scdn.co/mp3-preview/c6ea7197c02430f1...
# 59  https://p.scdn.co/mp3-preview/52afab05fe6b6da5...
# 60  https://p.scdn.co/mp3-preview/899caa29746e4ea3...
# 61  https://p.scdn.co/mp3-preview/7378227189ebb06c...
# 63  https://p.scdn.co/mp3-preview/53e072ec1b741fd5...
# 64  https://p.scdn.co/mp3-preview/609d21d24ab7a92e...
# 65  https://p.scdn.co/mp3-preview/a9d9d2d68603e22d...
# 69  https://p.scdn.co/mp3-preview/ffc0e31e3685cae5...
# 70  https://p.scdn.co/mp3-preview/406c96692d6f572b...
# 73  https://p.scdn.co/mp3-preview/7230a11dd762c2c6...
# 78  https://p.scdn.co/mp3-preview/a9e29b17391150ef...
# 79  https://p.scdn.co/mp3-preview/dcddd0ebee02d914...
# 82  https://p.scdn.co/mp3-preview/e92c9e07cccf4b21...
# 83  https://p.scdn.co/mp3-preview/9ecf91e6cfd4a85b...
# 85  https://p.scdn.co/mp3-preview/92d40a2ae211cceb...
# 87  https://p.scdn.co/mp3-preview/0c70536dadb45c6f...
# 88  https://p.scdn.co/mp3-preview/1f826380a449ec9a...
# 90  https://p.scdn.co/mp3-preview/42294fbcc0af128f...
# 96  https://p.scdn.co/mp3-preview/9364e08b3d1452c0...
# 97  https://p.scdn.co/mp3-preview/b50deda939ea2475...
# 98  https://p.scdn.co/mp3-preview/a4b1e550d564f7c6...
# 99  https://p.scdn.co/mp3-preview/6a2c40a2caaaaea4...

# %%
tracks_df.to_csv('disco7.csv', index=False)
