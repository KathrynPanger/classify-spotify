# %%
from spotipy.oauth2 import SpotifyClientCredentials
import matplotlib.pyplot as plt
import pandas as pd
import requests
import spotipy 
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import requests
import json
import re
import requests
import urllib.request
import re
from bs4 import BeautifulSoup
import os

# %%
from config import cid
from config import secret
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
dataframe_1=pd.read_csv("h_metal_track_dataframe_1.csv")
dataframe_1.head()
# Out:
#    Unnamed: 0        Genre           Track Name                Track ID  \
# 0           0  heavy-metal        The Unknowing  0NDV8dj1wP5sOi07rBYcTy
# 1           1  heavy-metal             Overkill  2O3BRyrdPgauBAAH5vxxvc
# 2           2  heavy-metal    Angels Don't Kill  2DheMnbW4bvwIMqPzQ3vKd
# 3           3  heavy-metal            Stillborn  6TRuW1ZgKCCk24uCuhfo7r
# 4           4  heavy-metal  An Eternity Of Lies  3gCXTYYYSWU9yJiFYjgOpQ
#
#                                         Preview_link
# 0  https://p.scdn.co/mp3-preview/c29b7958c5f883e4...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
dataframe_2=pd.read_csv("h_metal_track_dataframe_2.csv")
dataframe_2.head()
# Out:
#    Unnamed: 0        Genre                             Track Name  \
# 0           0  heavy-metal  What a Horrible Night to Have a Curse
# 1           1  heavy-metal                                   Halo
# 2           2  heavy-metal                          Mouth for War
# 3           3  heavy-metal                     Stabbing the Drama
# 4           4  heavy-metal                               Amaranth
#
#                  Track ID                                       Preview_link
# 0  430xmK8Tw4J4VG8PxCqO4I  https://p.scdn.co/mp3-preview/4fdf87f9b01141ea...
# 1  5nksa8EqKHSWO9WBj6DnmS  https://p.scdn.co/mp3-preview/538dbe97d64c481c...
# 2  6rkeaQRCWZxwkjhyqgxjXi  https://p.scdn.co/mp3-preview/cb8116effd9beb66...
# 3  4GRDYaJQWP9wd9HAga6IB1                                                NaN
# 4  6eIveQ3SRArBxIE0RsUQKE                                                NaN

# %%
dataframe_3 = pd.read_csv("h_metal_track_dataframe_3.csv")
dataframe_3.head()
# Out:
#    Unnamed: 0        Genre             Track Name                Track ID  \
# 0           0  heavy-metal  Children of the Grave  00iV838pAEznn1qLoG8Rxy
# 1           1  heavy-metal        Cloud Connected  1FCrFcZRoKLIaZ6JDocHMf
# 2           2  heavy-metal              The Price  1zhslrTnZTCu5yHw8MjUF7
# 3           3  heavy-metal      Élan - Radio Edit  0kHJ1gFEeaGBFRcOE2LQ5m
# 4           4  heavy-metal             Desolation  0asHedzNrLSCVDq0SW5gwy
#
#                                         Preview_link
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  https://p.scdn.co/mp3-preview/976e1ef9d19a5e67...
# 4  https://p.scdn.co/mp3-preview/5e7c5dc783c62dfe...

# %%
dataframe_4 = pd.read_csv("h_metal_track_dataframe_4.csv")
dataframe_4.head()
# Out:
#    Unnamed: 0        Genre                             Track Name  \
# 0           0  heavy-metal                            Messe Noire
# 1           1  heavy-metal                                 Mikasa
# 2           2  heavy-metal  2 Minutes to Midnight - 1998 Remaster
# 3           3  heavy-metal                      Under Bergets Rot
# 4           4  heavy-metal                  Princess of the Night
#
#                  Track ID                                       Preview_link
# 0  0buZkaEEaRLoEfVctp64sb  https://p.scdn.co/mp3-preview/65d3e717d1cd1a2f...
# 1  3WERezDCiZxIDfghCax9uJ  https://p.scdn.co/mp3-preview/9e123820bdd9bd2e...
# 2  6aYXSH9JZrD30Av2KlAOMY                                                NaN
# 3  4ho1rQiv9MAInf3SEeywxK                                                NaN
# 4  2Q6Knqq0R7baKPuo0bgMCU  https://p.scdn.co/mp3-preview/2ce3299890a64af6...

# %%
dataframe_5 = pd.read_csv("h_metal_track_dataframe_5.csv")
dataframe_5.head()
# Out:
#    Unnamed: 0        Genre   Track Name                Track ID  \
# 0           0  heavy-metal    Year Zero  1MdC1WDXrEzrpQwxb5mEXC
# 1           1  heavy-metal     Madhouse  6DRvu6LgU0wRF6Yr7WHRji
# 2           2  heavy-metal  War Eternal  0EV08ZFYMYsc8hCwDuC97H
# 3           3  heavy-metal  Heavy Heart  0YAVTydrJotYSpqP9WNuCF
# 4           4  heavy-metal  I, Dementia  1iDugXsvJ2cb5snhHP3t41
#
#                                         Preview_link
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  https://p.scdn.co/mp3-preview/3fbf4ef64e22e405...

# %%
dataframe_6 = pd.read_csv("h_metal_track_dataframe_6.csv")
dataframe_6.head()
# Out:
#    Unnamed: 0        Genre     Track Name                Track ID  \
# 0           0  heavy-metal  Digital World  2KhwmD6OTFJtlq6PVu9mI5
# 1           1  heavy-metal  Night Witches  4GyoRIx9au0OSRrqbArkia
# 2           2  heavy-metal     Holy Diver  57fqmDaokbxZ3TaB0jp39q
# 3           3  heavy-metal         Cirice  19yy8kd0JBWpvobwZDw20l
# 4           4  heavy-metal        Endzeit  2abSIRLYyz5YFr6TCSTaFd
#
#                                         Preview_link
# 0                                                NaN
# 1                                                NaN
# 2  https://p.scdn.co/mp3-preview/2b39f877d26df997...
# 3                                                NaN
# 4                                                NaN

# %%
dataframe_7 = pd.read_csv("h_metal_track_dataframe_7.csv")
dataframe_7.head()
# Out:
#    Unnamed: 0        Genre             Track Name                Track ID  \
# 0           0  heavy-metal                  Bleed  5p2sCetlJ6D0KiBljKwmLb
# 1           1  heavy-metal      Master Of Puppets  6NwbeybX6TDtXlpXvnUOZC
# 2           2  heavy-metal      I Could Care Less  7sI7rhcEbNyI78SsNMO2A8
# 3           3  heavy-metal                Carrion  0xfWKcNu13xxXQ2GT0P09M
# 4           4  heavy-metal  Children of the Grave  00iV838pAEznn1qLoG8Rxy
#
#                                         Preview_link
# 0                                                NaN
# 1                                                NaN
# 2  https://p.scdn.co/mp3-preview/6a66e0ddd3c6bcc9...
# 3  https://p.scdn.co/mp3-preview/d27edbfabd53cf5c...
# 4                                                NaN

# %%
#dataframe_8 = pd.read_csv("h_metal_track_dataframe_8.csv")
#dataframe_8.head()

# %%
final_df = pd.concat([dataframe_1, dataframe_2, dataframe_3, dataframe_4, dataframe_5,dataframe_6,dataframe_7], ignore_index=True)
final_df
# Out:
#      Unnamed: 0        Genre  \
# 0             0  heavy-metal
# 1             1  heavy-metal
# 2             2  heavy-metal
# 3             3  heavy-metal
# 4             4  heavy-metal
# 5             5  heavy-metal
# 6             6  heavy-metal
# 7             7  heavy-metal
# 8             8  heavy-metal
# 9             9  heavy-metal
# 10           10  heavy-metal
# 11           11  heavy-metal
# 12           12  heavy-metal
# 13           13  heavy-metal
# 14           14  heavy-metal
# 15           15  heavy-metal
# 16           16  heavy-metal
# 17           17  heavy-metal
# 18           18  heavy-metal
# 19           19  heavy-metal
# 20           20  heavy-metal
# 21           21  heavy-metal
# 22           22  heavy-metal
# 23           23  heavy-metal
# 24           24  heavy-metal
# 25           25  heavy-metal
# 26           26  heavy-metal
# 27           27  heavy-metal
# 28           28  heavy-metal
# 29           29  heavy-metal
# ..          ...          ...
# ...

# %%
disco_merge = final_df.dropna(how = 'any')
disco_merge = disco_merge.drop_duplicates(subset=['Track ID'],keep='last')
disco_merge.reset_index()
disco_merge.drop(['Unnamed: 0'], axis=1)
disco_merge.to_csv("h_metal.csv")

# %%
h_metal = pd.read_csv("h_metal.csv")
h_metal
# Out:
#      Unnamed: 0  Unnamed: 0.1        Genre  \
# 0             0             0  heavy-metal
# 1             5             5  heavy-metal
# 2            11            11  heavy-metal
# 3            23            23  heavy-metal
# 4            35            35  heavy-metal
# 5            37            37  heavy-metal
# 6            51            51  heavy-metal
# 7            71            71  heavy-metal
# 8            76            76  heavy-metal
# 9            92            92  heavy-metal
# 10           97            97  heavy-metal
# 11          119            19  heavy-metal
# 12          124            24  heavy-metal
# 13          132            32  heavy-metal
# 14          136            36  heavy-metal
# 15          137            37  heavy-metal
# 16          153            53  heavy-metal
# 17          162            62  heavy-metal
# 18          164            64  heavy-metal
# 19          198            98  heavy-metal
# 20          203             3  heavy-metal
# ...

# %%
preview_list = h_metal['Preview_link'].tolist()
print(preview_list)
genre_list = h_metal['Genre'].tolist()
print(genre_list)
track_name_list = h_metal['Track Name'].tolist()
print(track_name_list)
# Out:
# ['https://p.scdn.co/mp3-preview/c29b7958c5f883e413a06922abecb7a62e67781e?cid=577c3414ccf54576a289735f10e3ee13', 'https://p.scdn.co/mp3-preview/782066990801fdfcea69a83918f637bac27ad26b?cid=577c3414ccf54576a289735f10e3ee13', 'https://p.scdn.co/mp3-preview/256a022498c4ef7a71a87c89f77e226bb3951976?cid=577c3414ccf54576a289735f10e3ee13', 'https://p.scdn.co/mp3-preview/3f43b48b3ed14aad561ec0a7671ca7851aa971b2?cid=577c3414ccf54576a289735f10e3ee13', 'https://p.scdn.co/mp3-preview/01829583c63f5a07a6225b66d877a16a416ebe3f?cid=577c3414ccf54576a289735f10e3ee13', 'https://p.scdn.co/mp3-preview/a9e8d8f1bddb8b94b4ea9c7d47d36693ffe9d68a?cid=577c3414ccf54576a289735f10e3ee13', 'https://p.scdn.co/mp3-preview/ec3d71c51bac44e111ed3d11f9a233bf74f572b8?cid=577c3414ccf54576a289735f10e3ee13', 'https://p.scdn.co/mp3-preview/7b04a0fcdc3707fd8d11f0e9b75fa2e3fdda5f48?cid=577c3414ccf54576a289735f10e3ee13', 'https://p.scdn.co/mp3-preview/49d8d3b2f2e6e13b338a8563ce2fd0a1834f2b4b?cid=577c3414ccf54576a289735f10e3ee13'
# ...

# %%
os.chdir('/Users/heesungshim/Desktop/2_Homework_BTC/final_group_project/heavy_metal/heavy_metal_mp3')
for n, a_link in enumerate(preview_list):
    track_name = track_name_list[n].replace(' ', '_')
    track_name = track_name.replace('""', "''")
    track_name = track_name.replace("'", '_')
    track_name = track_name.replace('(', '_')
    track_name = track_name.replace(')', '_')
    track_name = track_name.replace('&', '_')
    track_name = track_name.replace('-', '_')
    track_name = track_name.replace('/', '_')
    a_output = genre_list[n]+'_'+str(n)+'_'+ track_name +'.mp3'
    cmd = "wget -O %s %s" % (a_output, a_link)
    print(cmd)
    os.system(cmd)
# Out:
# wget -O heavy-metal_0_The_Unknowing.mp3 https://p.scdn.co/mp3-preview/c29b7958c5f883e413a06922abecb7a62e67781e?cid=577c3414ccf54576a289735f10e3ee13
# wget -O heavy-metal_1_1.618.mp3 https://p.scdn.co/mp3-preview/782066990801fdfcea69a83918f637bac27ad26b?cid=577c3414ccf54576a289735f10e3ee13
# wget -O heavy-metal_2_Bleak.mp3 https://p.scdn.co/mp3-preview/256a022498c4ef7a71a87c89f77e226bb3951976?cid=577c3414ccf54576a289735f10e3ee13
# wget -O heavy-metal_3_Heathen_Horde.mp3 https://p.scdn.co/mp3-preview/3f43b48b3ed14aad561ec0a7671ca7851aa971b2?cid=577c3414ccf54576a289735f10e3ee13
# wget -O heavy-metal_4_Cry_Of_The_Black_Birds.mp3 https://p.scdn.co/mp3-preview/01829583c63f5a07a6225b66d877a16a416ebe3f?cid=577c3414ccf54576a289735f10e3ee13
# wget -O heavy-metal_5_Hail_and_Kill.mp3 https://p.scdn.co/mp3-preview/a9e8d8f1bddb8b94b4ea9c7d47d36693ffe9d68a?cid=577c3414ccf54576a289735f10e3ee13
# ...

# %%
track_name_list[0]
genre_list[0]
